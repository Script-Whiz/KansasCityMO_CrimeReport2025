# %% [markdown]
# Your Rideshare Bodyguard!... safety report, by Deborah Thomas

# %% [markdown]
# <h1 style="color: blue;">Introduction</h1>

# %% [markdown]
# ## Identifying High-Risk Areas for Rideshare Safety in Kansas City, MO.
# Help VendiSafe create a data-driven approach to identifying high-risk locations in Kansas City, MO, where drivers and passengers may need extra safety measures. Kansas City is part of Jackson, Clay, Platte, and Cass counties.

# %% [markdown]
# <h1 style="color: blue;">Import Libraries.</h1>

# %%
import pdfplumber
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h1 style="color: blue;">Read in Dataset.</h1>

# %% [markdown]
# - Description of where dataset comes from

# %% [markdown]
# Kansas City Open Data Portal – Local government datasets, including crime and incident data. 2019-2024 KCPD combined reports. The dataset comes from [https://data.kcmo.org/Crime/KCPD-Crime-Data-2019-to-2024/egkn-fji8/about_data](https://data.kcmo.org/Crime/KCPD-Crime-Data-2019-to-2024/egkn-fji8/about_data).
#
# Map of the Police Department territories: [View Map of Police Department Territories](https://kcpd.maps.arcgis.com/apps/webappviewer/index.html?id=24c6239af6654e4aa1d9fb196d01ffb2).
#
# These are the neighborhoods of Kansas City, MO: [Wikipedia - Neighborhoods of Kansas City, Missouri](https://en.wikipedia.org/wiki/Neighborhoods_of_Kansas_City,_Missouri).

# %%
dtypes = {
    'Description': 'str',
    'City': 'str',
    'Area': 'str',
    'Location': 'str'
}

# %%
KS2 = pd.read_csv("../datasets/KCPD_Crime_Data_KC_OpenDataPortal_2019_to_2024_20250403.csv", dtype=dtypes, low_memory=False)

# %%
display(KS2.head(100))
# Out:
#      Report_No           Reported_Date Reported_Time               From_Date  \
# 0    190002679  01/21/2019 12:00:00 AM          8:34                     NaN
# 1   KC20070693  10/15/2020 12:00:00 AM          9:37  01/01/2016 12:00:00 AM
# 2   KC19030380  04/25/2019 12:00:00 AM         20:51  04/25/2019 12:00:00 AM
# 3   KC19044992  06/17/2019 12:00:00 AM          2:57  06/17/2019 12:00:00 AM
# 4   KC19044691  06/15/2019 12:00:00 AM         17:22  06/15/2019 12:00:00 AM
# ..         ...                     ...           ...                     ...
# 95  KC20012154  02/17/2020 12:00:00 AM         12:30  02/17/2020 12:00:00 AM
# 96  KC20070613  10/14/2020 12:00:00 AM         18:46  10/14/2020 12:00:00 AM
# 97  KC20013211  02/21/2020 12:00:00 AM         12:46  02/21/2020 12:00:00 AM
# 98  KC20004050  01/16/2020 12:00:00 AM         21:46  01/16/2020 12:00:00 AM
# 99  KC20017418  03/08/2020 12:00:00 AM         11:17  03/08/2020 12:00:00 AM
#
#    From_Time To_Date To_Time                        Offense IBRS  \
# 0        NaN     NaN     NaN           Fraud/Confidence Gam  26A
# 1      10:08     NaN     NaN        Sexual Abuse - Juvenile  NaN
# 2      22:35     NaN     NaN  City/Municipal Warrant Arrest  NaN
# 3       2:57     NaN     NaN                Rape - Juvenile  11A
# 4      16:06     NaN     NaN            Stealing – Shoplift  NaN
# ..       ...     ...     ...                            ...  ...
# 95     12:44     NaN     NaN                           Rape  11A
# 96     19:52     NaN     NaN  City/Municipal Warrant Arrest  NaN
# 97     13:00     NaN     NaN                    Stolen Auto  35A
# 98     21:46     NaN     NaN  City/Municipal Warrant Arrest  NaN
# 99     11:18     NaN     NaN                      Dead Body  NaN
#
#                    Description  ...  Area DVFlag  Involvement Race  Sex   Age  \
# 0                          NaN  ...   NaN      U          SUS    W    M  28.0
# 1                          NaN  ...  OSPD      N          VIC    W    F   NaN
# 2                          NaN  ...  OSPD      N  ARR CHA SUS    W    F  34.0
# 3                Forcible Rape  ...   EPD      N          SUS    B    M   NaN
# 4                          NaN  ...   CPD      N          VIC  NaN  NaN   NaN
# ..                         ...  ...   ...    ...          ...  ...  ...   ...
# 95               Forcible Rape  ...   SPD      N      CMP VIC    B    F   NaN
# 96                         NaN  ...  OSPD      N      ARR CHA    W    F  36.0
# 97  Drug / Narcotic Violations  ...   MPD      N          VIC  NaN  NaN   NaN
# 98                         NaN  ...  OSPD      N  ARR CHA SUS    B    M  55.0
# 99                         NaN  ...   MPD      N          VIC    B    M  43.0
#
#    Fire Arm Used Flag Location Age_Range                       Geo_Location1
# 0               False      NaN       NaN  POINT (-92.477746617 38.367982746)
# 1               False      NaN       NaN                                 NaN
# 2               False      NaN       NaN  POINT (-94.419408416 39.245010036)
# 3               False      NaN       NaN  POINT (-94.541545037 39.102210418)
# 4               False      NaN       NaN  POINT (-94.591899968 39.042694983)
# ..                ...      ...       ...                                 ...
# 95              False      NaN       NaN   POINT (-94.49564697 38.941580983)
# 96              False      NaN       NaN  POINT (-94.419408416 39.245010036)
# 97              False      NaN       NaN  POINT (-94.608049968 38.925709911)
# 98              False      NaN       NaN  POINT (-94.781052433 39.372291405)
# 99              False      NaN       NaN  POINT (-94.556323986 39.017482008)
#
# [100 rows x 25 columns]

# %%
print(KS2.shape)
# Out:
# (522907, 25)

# %%
KS2.Reported_Date.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         01/21/2019 12:00:00 AM
# 1         10/15/2020 12:00:00 AM
# 2         04/25/2019 12:00:00 AM
# 3         06/17/2019 12:00:00 AM
# 4         06/15/2019 12:00:00 AM
#                    ...
# 522902    12/29/2022 12:00:00 AM
# 522903    04/27/2022 12:00:00 AM
# 522904    12/15/2022 12:00:00 AM
# 522905    12/09/2022 12:00:00 AM
# 522906    12/20/2022 12:00:00 AM
# Name: Reported_Date, Length: 522907, dtype: object>

# %%
KS2.Involvement.value_counts()
# Out:
# Involvement
# VIC                    251776
# SUS                    110694
# ARR CHA SUS             65386
# CMP VIC                 38239
# VIC SUS                  8003
#                         ...
# VIC SWM SUS                 1
# VOD PED                     1
# ARR CHA INA SOC VDR         1
# INA SUS A01 CHA PNT         1
# SUS DEC VDR                 1
# Name: count, Length: 697, dtype: int64

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522907 entries, 0 to 522906
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Report_No           522907 non-null  object
#  1   Reported_Date       522907 non-null  object
#  2   Reported_Time       522907 non-null  object
#  3   From_Date           522827 non-null  object
#  4   From_Time           522807 non-null  object
#  5   To_Date             246508 non-null  object
#  6   To_Time             178837 non-null  object
#  7   Offense             522907 non-null  object
#  8   IBRS                468296 non-null  object
#  9   Description         442795 non-null  object
#  10  Beat                521093 non-null  object
#  11  Address             522888 non-null  object
#  12  City                522866 non-null  object
#  13  Zip Code            478639 non-null  object
#  14  Rep_Dist            416713 non-null  object
#  15  Area                520208 non-null  object
#  16  DVFlag              522907 non-null  object
#  17  Involvement         522907 non-null  object
#  18  Race                453119 non-null  object
#  19  Sex                 459675 non-null  object
#  20  Age                 384716 non-null  float64
#  21  Fire Arm Used Flag  522907 non-null  bool
#  22  Location            456405 non-null  object
#  23  Age_Range           237176 non-null  object
#  24  Geo_Location1       522862 non-null  object
# dtypes: bool(1), float64(1), object(23)
# memory usage: 96.2+ MB

# %% [markdown]
# - These columns need to be dropped: Report_No, From_Time, To_Date, To_Time, Involvement, Race, Sex, Age, Age_Range.
# - These columns need to be converted to datetime: Reported_Date, Reported_Time, From_Date.
# - Reported_Date column needs to have 12:00 AM removed because all values have it.
# - Fire Arm Used Flag column naming needs to have spaces removed.

# %% [markdown]
# <h1 style="color: blue;">Clean the Data</h1>

# %% [markdown]
# - Drop unecessary columns.

# %%
columns_to_drop = ['Report_No', 'From_Time', 'To_Date', 'To_Time', 'IBRS', 'Involvement', 'Race', 'Sex', 'Age', 'Age_Range']
KS2 = KS2.drop(columns=columns_to_drop)

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522907 entries, 0 to 522906
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Reported_Date       522907 non-null  object
#  1   Reported_Time       522907 non-null  object
#  2   From_Date           522827 non-null  object
#  3   Offense             522907 non-null  object
#  4   Description         442795 non-null  object
#  5   Beat                521093 non-null  object
#  6   Address             522888 non-null  object
#  7   City                522866 non-null  object
#  8   Zip Code            478639 non-null  object
#  9   Rep_Dist            416713 non-null  object
#  10  Area                520208 non-null  object
#  11  DVFlag              522907 non-null  object
#  12  Fire Arm Used Flag  522907 non-null  bool
#  13  Location            456405 non-null  object
#  14  Geo_Location1       522862 non-null  object
# dtypes: bool(1), object(14)
# memory usage: 56.4+ MB

# %% [markdown]
# 'Reported_Date', 'Reported_Time', 'Offense', 'DVFlag', 'Fire Arm Used Flag' are the only columns that have no missing data.

# %%
print(KS2.shape)
# Out:
# (522907, 15)

# %% [markdown]
# - Drop duplicates

# %%
KS2 = KS2.drop_duplicates()

# %%
print(KS2.shape)
# Out:
# (312430, 15)

# %%
522907 - 312430
# Out:
# 210477

# %% [markdown]
# #### 210,477 rows were duplicates and were dropped.

# %% [markdown]
# <h3 style="color: blue;">Clean Area Column</h3>

# %% [markdown]
# - Look for NaN in Area

# %%
nan_entries = KS2[KS2['Area'].isna()]

print("Entries where Area is NaN:")
display(nan_entries.head(5))
# Out:
# Entries where Area is NaN:
#              Reported_Date Reported_Time               From_Date  \
# 0   01/21/2019 12:00:00 AM          8:34                     NaN
# 5   03/28/2019 12:00:00 AM         12:01                     NaN
# 6   04/12/2019 12:00:00 AM          9:31  04/08/2019 12:00:00 AM
# 7   05/09/2019 12:00:00 AM         13:15  09/17/2018 12:00:00 AM
# 16  03/14/2019 12:00:00 AM         12:27  03/06/2019 12:00:00 AM
#
#                  Offense               Description Beat               Address  \
# 0   Fraud/Confidence Gam                       NaN  NaN                   NaN
# 5   Aggravated Assault (                       NaN  NaN                   NaN
# 6            Stolen Auto       Motor Vehicle Theft  NaN        4500  S BENTON
# 7                Forgery  Counterfeiting / Forgery  533  10700  STATE LINE RD
# 16        Misc Violation                       NaN  NaN             8611 21ST
#
#            City Zip Code Rep_Dist Area DVFlag  Fire Arm Used Flag Location  \
# 0           NaN      NaN      NaN  NaN      U               False      NaN
# 5           NaN      NaN      NaN  NaN      U                True      NaN
# 6   KANSAS CITY    64130      NaN  NaN      N               False      NaN
# 7   KANSAS CITY    64114      NaN  NaN      N               False      NaN
# 16  KANSAS CITY    64126      NaN  NaN      U               False      NaN
#
#                          Geo_Location1
# 0   POINT (-92.477746617 38.367982746)
# 5   POINT (-92.477746617 38.367982746)
# 6   POINT (-94.551136007 39.044326017)
# 7   POINT (-94.608049968 38.925709911)
# 16  POINT (-94.483472004 39.083929001)

# %% [markdown]
# - Change NaN, in Area, to 'Unknown'

# %%
KS2['Area'] = KS2['Area'].fillna('Unknown')

# %% [markdown]
# - Inspect police department territories.

# %%
area_counts = KS2['Area'].value_counts().reset_index()
area_counts.columns = ['Area', 'Count']
print(area_counts)
# Out:
#       Area  Count
# 0      CPD  87352
# 1      EPD  74334
# 2      MPD  56777
# 3      SPD  34250
# 4      SCP  28540
# 5      NPD  26861
# 6     OSPD   2668
# 7  Unknown   1636
# 8      PD1     11
# 9     SCPD      1

# %%
filtered_df = KS2[KS2['Area'] == 'PD1']

display(filtered_df)
# Out:
#                  Reported_Date Reported_Time               From_Date  \
# 30791   03/21/2019 12:00:00 AM         13:27  06/24/2016 12:00:00 AM
# 68754   01/17/2019 12:00:00 AM         18:44  01/11/2019 12:00:00 AM
# 80945   03/02/2019 12:00:00 AM         12:36  03/01/2019 12:00:00 AM
# 82702   02/13/2019 12:00:00 AM         16:18  01/01/2019 12:00:00 AM
# 82981   01/28/2019 12:00:00 AM          9:50  01/24/2019 12:00:00 AM
# 83061   03/07/2019 12:00:00 AM          8:24  03/06/2019 12:00:00 AM
# 85424   02/01/2019 12:00:00 AM         16:00  01/18/2019 12:00:00 AM
# 86042   03/18/2019 12:00:00 AM          8:00  03/11/2019 12:00:00 AM
# 89317   02/26/2019 12:00:00 AM         11:20  02/26/2019 12:00:00 AM
# 96432   02/17/2019 12:00:00 AM          2:14  02/16/2019 12:00:00 AM
# 104604  03/23/2019 12:00:00 AM         19:39  01/01/1996 12:00:00 AM
#
#                      Offense Description Beat             Address  \
# 30791     Stealing From Auto         NaN  999   9999 S UNKNOWN ST
# 68754         Statutory Rape         NaN  999  9900  S UNKNOWN ST
# 80945   Credit/Debit/ATM Car         NaN  999   9999 S UNKNOWN ST
# 82702   Stealing from Buildi         NaN  999   1000 BERKLEY PKWY
# 82981   Credit/Debit/ATM Car         NaN  999   9999 S UNKNOWN ST
# 83061   Fraud/Confidence Gam         NaN  999   9999 S UNKNOWN ST
# 85424         Identity Theft         NaN  999   9999 S UNKNOWN ST
# 86042   Credit/Debit/ATM Car         NaN  999   9999 S UNKNOWN ST
# 89317     Stealing From Auto         NaN  999   9999 S UNKNOWN ST
# 96432     Stealing From Auto         NaN  999   9999 S UNKNOWN ST
# 104604        Statutory Rape         NaN  999  9900  S UNKNOWN ST
#
#                City Zip Code Rep_Dist Area DVFlag  Fire Arm Used Flag  \
# 30791   KANSAS CITY    99999   PKC000  PD1      N               False
# 68754   KANSAS CITY      NaN   PKC000  PD1      U               False
# 80945   KANSAS CITY    99999   PKC000  PD1      U               False
# 82702   KANSAS CITY    64120   PKC000  PD1      U               False
# 82981   KANSAS CITY    99999   PKC000  PD1      U               False
# 83061   KANSAS CITY    99999   PKC000  PD1      U               False
# 85424   KANSAS CITY    99999   PKC000  PD1      U               False
# 86042   KANSAS CITY    99999   PKC000  PD1      U               False
# 89317   KANSAS CITY    99999   PKC000  PD1      N               False
# 96432   KANSAS CITY      NaN   PKC000  PD1      U               False
# 104604  KANSAS CITY    64106   PKC000  PD1      N               False
#
#                                                  Location  \
# 30791                                                 NaN
# 68754                                                 NaN
# 80945                                                 NaN
# 82702   1000 BERKLEY PKWY\nKANSAS CITY 64120\n(39.1151...
# 82981                                                 NaN
# 83061                                                 NaN
# 85424                                                 NaN
# 86042                                                 NaN
# 89317                                                 NaN
# 96432                                                 NaN
# 104604                                                NaN
#
#                              Geo_Location1
# 30791           POINT (-94.58311 39.10344)
# 68754           POINT (-94.58311 39.10344)
# 80945           POINT (-94.58311 39.10344)
# 82702   POINT (-94.572775985 39.115939992)
# 82981           POINT (-94.58311 39.10344)
# 83061           POINT (-94.58311 39.10344)
# 85424           POINT (-94.58311 39.10344)
# 86042           POINT (-94.58311 39.10344)
# 89317           POINT (-94.58311 39.10344)
# 96432           POINT (-94.58311 39.10344)
# 104604         POINT (-94.575675 39.10424)

# %% [markdown]
# ### Kansas City, MO Divisions
# - **CPD** (Central Police Department, located in the center west. Includes West Kansas City, MO)
# - **EPD** (East Patrol, located in the center east. Includes East Kansas City, MO)
# - **MPD** (Metro Police Department, located in the center south)
# - **SPD** (South Patrol Division)
# - **SCP** (Shoal Creek Police Department, located in the Northeast)
# - **NPD** (North Police Department, located in the Northwest. Includes Wetherby Lake, Parkville, Gladstone, North Kansas City)
#
# - **SCPD** Typo. Needs to change to 'SCP'
#
# - **OSPD** (located in the town of Liberty)
# - **PD1** Typo. Looking at the addresses, BERKLEY PKWY is located in the CPD district. Changing 'PD1' to 'CPD'.
#
#
# https://data.kcmo.org/dataset/Police-Divisions/pxe5-449t

# %% [markdown]
# - change PD1 to CPD

# %%
KS2.loc[KS2['Area'] == 'PD1', 'Area'] = 'CPD'

# %% [markdown]
# - change SCPD to SCP

# %%
KS2.loc[KS2['Area'] == 'SCPD', 'Area'] = 'SCP'

# %%
KS2.Area.value_counts()
# Out:
# Area
# CPD        87363
# EPD        74334
# MPD        56777
# SPD        34250
# SCP        28541
# NPD        26861
# OSPD        2668
# Unknown     1636
# Name: count, dtype: int64

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312430 entries, 0 to 522904
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Reported_Date       312430 non-null  object
#  1   Reported_Time       312430 non-null  object
#  2   From_Date           312389 non-null  object
#  3   Offense             312430 non-null  object
#  4   Description         255996 non-null  object
#  5   Beat                311344 non-null  object
#  6   Address             312424 non-null  object
#  7   City                312410 non-null  object
#  8   Zip Code            286082 non-null  object
#  9   Rep_Dist            247217 non-null  object
#  10  Area                312430 non-null  object
#  11  DVFlag              312430 non-null  object
#  12  Fire Arm Used Flag  312430 non-null  bool
#  13  Location            272151 non-null  object
#  14  Geo_Location1       312409 non-null  object
# dtypes: bool(1), object(14)
# memory usage: 36.1+ MB

# %% [markdown]
# Area now no longer has missing values.

# %% [markdown]
# <h3 style="color: blue;">Clean City Column</h3>

# %%
KS2.City.value_counts()
# Out:
# City
# KANSAS CITY      309261
# LIBERTY             594
# INDEPENDENCE        366
# PLATTE CITY         245
# GRANDVIEW           215
#                   ...
# AUSTIN                1
# LONGBEACH             1
# BOWLING GREED         1
# KANSAS CIT Y          1
# INDEPENDEANCE         1
# Name: count, Length: 227, dtype: int64

# %% [markdown]
# - Check for NaN

# %%
nan_citycount = KS2['City'].isna().sum()
print(f"Number of NaN values in 'City': {nan_citycount}")
# Out:
# Number of NaN values in 'City': 20

# %%
nan_city_rows = KS2[KS2['City'].isna()]
print("Rows with NaN values in 'City':")
display(nan_city_rows)
# Out:
# Rows with NaN values in 'City':
#                  Reported_Date Reported_Time               From_Date  \
# 0       01/21/2019 12:00:00 AM          8:34                     NaN
# 5       03/28/2019 12:00:00 AM         12:01                     NaN
# 44      01/21/2019 12:00:00 AM          8:34                     NaN
# 63      02/19/2019 12:00:00 AM         12:57                     NaN
# 733     02/19/2019 12:00:00 AM         12:57                     NaN
# 1982    03/29/2019 12:00:00 AM         21:43  03/29/2019 12:00:00 AM
# 2065    03/19/2019 12:00:00 AM         17:46  03/15/2019 12:00:00 AM
# 2101    03/27/2019 12:00:00 AM         22:05  03/23/2019 12:00:00 AM
# 2205    04/23/2019 12:00:00 AM         16:07  04/22/2019 12:00:00 AM
# 4168    03/28/2019 12:00:00 AM         12:46                     NaN
# 4809    04/24/2019 12:00:00 AM         17:30  04/24/2019 12:00:00 AM
# 7455    04/06/2019 12:00:00 AM         12:08  04/05/2019 12:00:00 AM
# 9560    04/12/2019 12:00:00 AM         14:27  04/12/2019 12:00:00 AM
# 11913   12/16/2019 12:00:00 AM         14:04  12/10/2019 12:00:00 AM
# 34074   08/08/2019 12:00:00 AM         13:10  08/08/2019 12:00:00 AM
# 51838   11/05/2019 12:00:00 AM          8:01  11/04/2019 12:00:00 AM
# 58327   10/21/2019 12:00:00 AM         10:03  09/21/2019 12:00:00 AM
# 133682  04/22/2020 12:00:00 AM          8:14  04/21/2020 12:00:00 AM
# 237349  03/25/2021 12:00:00 AM          7:28  03/25/2021 12:00:00 AM
# 268672  11/02/2021 12:00:00 AM         14:28  11/01/2021 12:00:00 AM
#
#                                                   Offense  \
# 0                                    Fraud/Confidence Gam
# 5                                    Aggravated Assault (
# 44                                                Forgery
# 63                                                Forgery
# 733                                  Fraud/Confidence Gam
# 1982                        Legacy Incident Report/Arrest
# 2065                                  Stealing – Shoplift
# 2101          Stealing from Auto (Auto Part or Accessory)
# 2205          Stealing from Auto (Auto Part or Accessory)
# 4168                                 Agg Assault - Drive-
# 4809    Felon/Prohibited Person in Possession of a Fir...
# 7455                                            Unfounded
# 9560                        Legacy Incident Report/Arrest
# 11913                                             Forgery
# 34074                                 Stealing – Shoplift
# 51838                                    Stealing – Other
# 58327                              Robbery (Armed Street)
# 133682                      Legacy Incident Report/Arrest
# 237349                       Outside State Warrant Arrest
# 268672                                    Property Damage
#
#                                    Description Beat  \
# 0                                          NaN  NaN
# 5                                          NaN  NaN
# 44                                         NaN  NaN
# 63                                         NaN  NaN
# 733                                        NaN  NaN
# 1982                                       NaN  112
# 2065                       Theft From Building  422
# 2101                  Theft From Motor Vehicle  113
# 2205    Theft of Vehicle Parts and Accessories  NaN
# 4168                                       NaN  NaN
# 4809                                       NaN  543
# 7455                                       NaN  113
# 9560                                       NaN  323
# 11913                                      NaN  112
# 34074                                      NaN  344
# 51838                                      NaN  322
# 58327                                      NaN  142
# 133682                                     NaN  112
# 237349                                     NaN  122
# 268672       Vandalism/Destruction of Property  111
#
#                                    Address City Zip Code Rep_Dist     Area  \
# 0                                      NaN  NaN      NaN      NaN  Unknown
# 5                                      NaN  NaN      NaN      NaN  Unknown
# 44                                     NaN  NaN      NaN      NaN  Unknown
# 63                                     NaN  NaN      NaN      NaN  Unknown
# 733                                    NaN  NaN      NaN      NaN  Unknown
# 1982                       1100  LOCUST ST  NaN      NaN      NaN      CPD
# 2065                      1600  NW 88TH ST  NaN      NaN      NaN      NPD
# 2101                        300  W 22ND ST  NaN      NaN      NaN      CPD
# 2205                         2500  MADISON  NaN      NaN      NaN  Unknown
# 4168                                   NaN  NaN      NaN      NaN  Unknown
# 4809    11800  BLUE RIDGE BLVD KANSAS CITY  NaN      NaN      NaN  Unknown
# 7455               E 18TH ST and WALNUT ST  NaN      NaN      NaN      CPD
# 9560        2600  PROSPECT AVE KANSAS CITY  NaN      NaN      NaN  Unknown
# 11913                       800  E 12TH ST  NaN      NaN      NaN      CPD
# 34074    5000  BLUE RIDGE CTOF KANSAS CITY  NaN      NaN      NaN  Unknown
# 51838                     3100  STADIUM DR  NaN      NaN      NaN      EPD
# 58327              E 38TH ST and FLORA AVE  NaN      NaN      NaN      CPD
# 133682         1100  LOCUST ST KANSAS CITY  NaN      NaN      NaN  Unknown
# 237349                    1100  TROOST AVE  NaN      NaN      NaN      CPD
# 268672                    1800  MADISON ST  NaN      NaN      NaN      CPD
#
#        DVFlag  Fire Arm Used Flag  \
# 0           U               False
# 5           U                True
# 44          U               False
# 63          U               False
# 733         U               False
# 1982        N               False
# 2065        N               False
# 2101        N               False
# 2205        N               False
# 4168        U                True
# 4809        N               False
# 7455        N               False
# 9560        N               False
# 11913       N               False
# 34074       N               False
# 51838       N               False
# 58327       N               False
# 133682      N               False
# 237349  FALSE               False
# 268672  FALSE               False
#
#                                                  Location  \
# 0                                                     NaN
# 5                                                     NaN
# 44                                                    NaN
# 63                                                    NaN
# 733                                                   NaN
# 1982            1100  LOCUST ST\n(37.895369, -122.061186)
# 2065                 1600  NW 88TH ST\n(39.2548, -94.599)
# 2101              300  W 22ND ST\n(41.847595, -87.927551)
# 2205                                                  NaN
# 4168                                                  NaN
# 4809    11800  BLUE RIDGE BLVD KANSAS CITY\n(38.910232...
# 7455     E 18TH ST and WALNUT ST\n(39.863779, -75.359812)
# 9560    2600  PROSPECT AVE KANSAS CITY\n(42.064863, -8...
# 11913             800  E 12TH ST\n(30.856878, -96.967045)
# 34074   5000  BLUE RIDGE CTOF KANSAS CITY\n(34.327668,...
# 51838           3100  STADIUM DR\n(42.272048, -85.627393)
# 58327    E 38TH ST and FLORA AVE\n(39.057042, -94.566175)
# 133682  1100  LOCUST ST KANSAS CITY\n(38.630186, -90.1...
# 237349                       POINT (-87.817227 41.866327)
# 268672                       POINT (-87.697941 42.031642)
#
#                              Geo_Location1
# 0       POINT (-92.477746617 38.367982746)
# 5       POINT (-92.477746617 38.367982746)
# 44      POINT (-92.477746617 38.367982746)
# 63      POINT (-92.477746617 38.367982746)
# 733     POINT (-92.477746617 38.367982746)
# 1982    POINT (-92.325135037 38.949202983)
# 2065    POINT (-94.598896007 39.254440004)
# 2101    POINT (-94.588031971 39.086729982)
# 2205    POINT (-94.595492033 39.081925014)
# 4168    POINT (-92.477746617 38.367982746)
# 4809          POINT (-94.509731 38.922341)
# 7455    POINT (-94.582490024 39.091760004)
# 9560            POINT (-94.58311 39.10344)
# 11913   POINT (-94.267773565 37.492953746)
# 34074           POINT (-94.58311 39.10344)
# 51838   POINT (-94.520104414 39.068501244)
# 58327   POINT (-94.566189989 39.057039981)
# 133682         POINT (-94.577321 39.10091)
# 237349  POINT (-94.569908685 39.100608412)
# 268672  POINT (-90.199859662 38.645199298)

# %% [markdown]
# - Change City to 'Unknown' if City is NaN and Address is Nan

# %%
KS2.loc[KS2['City'].isna() & KS2['Address'].isna(), 'City'] = 'Unknown'

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312430 entries, 0 to 522904
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Reported_Date       312430 non-null  object
#  1   Reported_Time       312430 non-null  object
#  2   From_Date           312389 non-null  object
#  3   Offense             312430 non-null  object
#  4   Description         255996 non-null  object
#  5   Beat                311344 non-null  object
#  6   Address             312424 non-null  object
#  7   City                312416 non-null  object
#  8   Zip Code            286082 non-null  object
#  9   Rep_Dist            247217 non-null  object
#  10  Area                312430 non-null  object
#  11  DVFlag              312430 non-null  object
#  12  Fire Arm Used Flag  312430 non-null  bool
#  13  Location            272151 non-null  object
#  14  Geo_Location1       312409 non-null  object
# dtypes: bool(1), object(14)
# memory usage: 36.1+ MB

# %% [markdown]
# - If Address is NaN, ZipCode is NaN, Location is NaN, then drop row.

# %%
# Drop rows where Address, Zip Code, and Location are all NaN
KS2 = KS2.dropna(subset=['Address', 'Beat', 'Zip Code', 'Location'], how='all')

# %% [markdown]
# - Look for typos in City

# %%
city_counts = KS2['City'].value_counts().reset_index()
city_counts.columns = ['City', 'Count']

# Display all rows
pd.set_option('display.max_rows', None)  # Show all rows in the output
print(city_counts)
# Out:
#                          City   Count
# 0                 KANSAS CITY  309261
# 1                     LIBERTY     594
# 2                INDEPENDENCE     366
# 3                 PLATTE CITY     245
# 4                   GRANDVIEW     215
# 5                 LEES SUMMIT     140
# 6                       INDEP     137
# 7                     RAYTOWN     128
# 8                  KANAS CITY     112
# 9                   GLADSTONE      87
# 10          NORTH KANSAS CITY      84
# 11               BLUE SPRINGS      80
# 12                     BELTON      79
# 13                  RIVERSIDE      61
# 14                        NKC      50
# 15                     KANSAS      45
# 16              HARRISONVILLE      44
# 17                SUGAR CREEK      34
# 18                       KCMO      27
# 19                 KANSA CITY      25
# 20                KASNAS CITY      24
# 21              OVERLAND PARK      24
# 22                    RAYMORE      22
# 23                        KCK      19
# 24               LEE'S SUMMIT      17
# 25                 LEE SUMMIT      17
# 26                         KC      15
# 27                   CLAYCOMO      15
# 28            PLEASANT VALLEY      14
# 29                KANSAS CTIY      13
# 30          EXCELSIOR SPRINGS      13
# 31                    LEAWOOD      12
# 32                 KANSASCITY      11
# 33                KANASA CITY      11
# 34                    JACKSON      10
# 35               KANASAS CITY      10
# 36                KNASAS CITY      10
# 37                 KANSAS CIY      10
# 38                 KANSAS CIT       7
# 39                  PARKVILLE       7
# 40             JEFFERSON CITY       7
# 41                  ST JOSEPH       7
# 42       KANSAS CITY MISSOURI       7
# 43   KANSAS CITY MISSOURI USA       6
# 44                    UNKNOWN       6
# 45                 KANSS CITY       5
# 46                    CAMERON       5
# 47                    SHAWNEE       5
# 48             KANSAS CITY MO       5
# 49                 KANSAS CTY       5
# 50                   HARRISON       5
# 51               KANSAS CITTY       5
# 52                     OLATHE       5
# 53               KANSAS C ITY       4
# 54               KANSAS CITIY       4
# 55                 PLATTSBURG       4
# 56               KANSASS CITY       4
# 57                 ST. JOSEPH       4
# 58                 SMITHVILLE       4
# 59              N KANSAS CITY       4
# 60                KANSA SCITY       3
# 61                  LAS VEGAS       3
# 62                      64106       3
# 63                    MERRIAM       3
# 64                   BRIGHTON       3
# 65                 KANSAS ITY       3
# 66                    MOBERLY       3
# 67                      64105       3
# 68                    LANSING       3
# 69               KANSASA CITY       3
# 70               PLATTE WOODS       3
# 71                 PLATTE CTY       2
# 72                     TOPEKA       2
# 73                      64123       2
# 74                     WALNUT       2
# 75                 KASAS CITY       2
# 76                    ATLANTA       2
# 77              KANSAS CITYTY       2
# 78                 KNSAS CITY       2
# 79                KANSSA CITY       2
# 80               HIGGINSVILLE       2
# 81                  PLATSBURG       2
# 82                       1604       2
# 83                    LICKING       2
# 84                     LENEXA       2
# 85                KAMSAS COTU       2
# 86                BLUE SUMMIT       2
# 87               KKANSAS CITY       2
# 88                      64111       2
# 89                   RANDOLPH       2
# 90                      AGNES       2
# 91               KANSAAS CITY       2
# 92                     FULTON       2
# 93                   COLUMBIA       2
# 94                 DODGE CITY       2
# 95                    MISSION       2
# 96                SAN ANTONIO       1
# 97                      LOGAN       1
# 98               KANSAS SCITY       1
# 99                   GLASTONE       1
# 100        DESERT HOT SPRINGS       1
# 101                 OAK GROVE       1
# 102              GRAIN VALLEY       1
# 103         NORTH BEACH MIAMI       1
# 104                KINGSVILLE       1
# 105                NORTHMOORE       1
# 106              HOUSTON LAKE       1
# 107                     TULSA       1
# 108                       UNK       1
# 109         EL DORADO SPRINGS       1
# 110                     MILLS       1
# 111                 ST. LOUIS       1
# 112          COLORADO SPRINGS       1
# 113              ROELAND PARK       1
# 114                FLORISSANT       1
# 115              BLUR SPRINGS       1
# 116                LEESSUMMIT       1
# 117             0VERLAND PARK       1
# 118              KANSAS CITHY       1
# 119             BLUES SPRINGS       1
# 120                  AMAZONIA       1
# 226             INDEPENDEANCE       1

# %% [markdown]
# There are some typos in the City names.

# %%
# Correct the values in the 'City' column
KS2['City'] = KS2['City'].replace({
    'KANAS CITY': 'KANSAS CITY',
    'KANSAS CITHY': 'KANSAS CITY',
    'KANSAS CIITY': 'KANSAS CITY',
    'KANNSAS CITY': 'KANSAS CITY',
    'KANSAS': 'KANSAS CITY',
    'KCMO': 'KANSAS CITY',
    'KANSA CITY': 'KANSAS CITY',
    'KANSAS CITYY': 'KANSAS CITY',
    'KANSAS COTY': 'KANSAS CITY',
    'KASNAS CITY': 'KANSAS CITY',
    'KASNAS CITYY': 'KANSAS CITY',
    'KASNAS COTY': 'KANSAS CITY',
    'KANASAS CITY': 'KANSAS CITY',
    'KCMO': 'KANSAS CITY',
    'KC': 'KANSAS CITY',
    'KANSASCITY': 'KANSAS CITY',
    'KANASA CITY': 'KANSAS CITY',
    'KANSAS CITY MISSOURI USA': 'KANSAS CITY',
    'KANSAS CIY': 'KANSAS CITY',
    'KNASAS CITY': 'KANSAS CITY',
    'KANSAS CTY': 'KANSAS CITY',
    'KANSAS CITY MISSOURI': 'KANSAS CITY',
    'KANSAS CITTY': 'KANSAS CITY',
    'KANSAS CIT': 'KANSAS CITY',
    'KANSAS CITYTY': 'KANSAS CITY',
    'KANSAS CITY MO': 'KANSAS CITY',
    'KANSAS ITY': 'KANSAS CITY',
    'KANSAS C ITY': 'KANSAS CITY',
    'KANSAS CITIY': 'KANSAS CITY',
    'KANSASS CITY': 'KANSAS CITY',
    'KANSS CITY': 'KANSAS CITY',
    'KASAS CITY': 'KANSAS CITY',
    'KANSASA CITY': 'KANSAS CITY',
    'KANSSA CITY': 'KANSAS CITY',
    'NORTH KANSAS CITY': 'KANSAS CITY',
    'KANSAAS CITY': 'KANSAS CITY',
    'KAMSAS CITY': 'KANSAS CITY',
    'KKANSAS CITY': 'KANSAS CITY',
    'KANSA SCITY': 'KANSAS CITY',
    'KANSAS CIRT': 'KANSAS CITY',
    'KANSAS CIRTY': 'KANSAS CITY',
    'KANAS': 'KANSAS CITY',
    'KANSAS CITU': 'KANSAS CITY',
    'KANSAS SCITY': 'KANSAS CITY',
    'KASNSAS CITY': 'KANSAS CITY',
    'KA NSAS CITY': 'KANSAS CITY',
    'KNSAS CITY': 'KANSAS CITY',
    'KANSAS CITH': 'KANSAS CITY',
    'KANSAS CTITY': 'KANSAS CITY',
    'KANSAS CIYT': 'KANSAS CITY',
    'KANSAS CITYT': 'KANSAS CITY',
    'KANSAS CITY 64117': 'KANSAS CITY',
    'KANSAS CIRY': 'KANSAS CITY',
    'KANSAS CIT Y ': 'KANSAS CITY',
    'N KANSAS CITY': 'KANSAS CITY',
    'KANSAS CITR': 'KANSAS CITY',
    'KASNAS COTY': 'KANSAS CITY',
    'KANSAS CI TY': 'KANSAS CITY',
    'KANSAS CIT Y': 'KANSAS CITY',
    'KANAS CTIY': 'KANSAS CITY',
    'KANSAS CTIY': 'KANSAS CITY',
    'KAMSAS COTU': 'KANSAS CITY',
    'KNASAS CTIY': 'KANSAS CITY',
    'KANSAS CITYY': 'KANSAS CITY',
    'KANSAS CITHY': 'KANSAS CITY',
    'KANSAS CIITY': 'KANSAS CITY',
    'KANNSAS CITY': 'KANSAS CITY',
    'KANSAS UNIT': 'KANSAS CITY',
    'KCK': 'KANSAS CITY',
    'UNKNOWN': 'KANSAS CITY',
    '1604': 'KANSAS CITY',
    '64114': 'KANSAS CITY',
    '64126': 'KANSAS CITY',
    '64130': 'KANSAS CITY',
    '64155': 'KANSAS CITY',
    '64132': 'KANSAS CITY',
    '64111': 'KANSAS CITY',
    '64108': 'KANSAS CITY',
    '64105': 'KANSAS CITY',
    '64106': 'KANSAS CITY',
    '64123': 'KANSAS CITY',
    
})

# %%
#KS2.City.value_counts()
city_counts = KS2['City'].value_counts().reset_index()
city_counts.columns = ['City', 'Count']

# Display all rows
pd.set_option('display.max_rows', None)  # Show all rows in the output
print(city_counts)
# Out:
#                    City   Count
# 0           KANSAS CITY  309805
# 1               LIBERTY     594
# 2          INDEPENDENCE     366
# 3           PLATTE CITY     245
# 4             GRANDVIEW     215
# 5           LEES SUMMIT     140
# 6                 INDEP     137
# 7               RAYTOWN     128
# 8             GLADSTONE      87
# 9          BLUE SPRINGS      80
# 10               BELTON      79
# 11            RIVERSIDE      61
# 12                  NKC      50
# 13        HARRISONVILLE      44
# 14          SUGAR CREEK      34
# 15        OVERLAND PARK      24
# 16              RAYMORE      22
# 17           LEE SUMMIT      17
# 18         LEE'S SUMMIT      17
# 19             CLAYCOMO      15
# 20      PLEASANT VALLEY      14
# 21    EXCELSIOR SPRINGS      13
# 22              LEAWOOD      12
# 23              JACKSON      10
# 24            PARKVILLE       7
# 25            ST JOSEPH       7
# 26       JEFFERSON CITY       7
# 27             HARRISON       5
# 28               OLATHE       5
# 29              SHAWNEE       5
# 30              CAMERON       5
# 31           SMITHVILLE       4
# 32           PLATTSBURG       4
# 33           ST. JOSEPH       4
# 34              LANSING       3
# 35             BRIGHTON       3
# 36              MERRIAM       3
# 37         PLATTE WOODS       3
# 38              MOBERLY       3
# 39            LAS VEGAS       3
# 40           PLATTE CTY       2
# 41         HIGGINSVILLE       2
# 42             RANDOLPH       2
# 43              ATLANTA       2
# 44               TOPEKA       2
# 45             COLUMBIA       2
# 46          BLUE SUMMIT       2
# 47              MISSION       2
# 48                AGNES       2
# 49               LENEXA       2
# 50           DODGE CITY       2
# 51               FULTON       2
# 52               WALNUT       2
# 53              LICKING       2
# 54            PLATSBURG       2
# 55    NORTH BEACH MIAMI       1
# 56         GRAIN VALLEY       1
# 57            OAK GROVE       1
# 58        0VERLAND PARK       1
# 59           LEESSUMMIT       1
# 60            LEXINGTON       1
# 61           FLORISSANT       1
# 62         ROELAND PARK       1
# 63     COLORADO SPRINGS       1
# 64            ST. LOUIS       1
# 65                MILLS       1
# 66    EL DORADO SPRINGS       1
# 67                  UNK       1
# 68            LITTLETON       1
# 69                TULSA       1
# 70                LOGAN       1
# 71         HOUSTON LAKE       1
# 72           NORTHMOORE       1
# 73           KINGSVILLE       1
# 74          SAN ANTONIO       1
# 75      WEST DES MOINES       1
# 76             GLASTONE       1
# 77        BLUES SPRINGS       1
# 78              COWGILL       1
# 79            PRINCETON       1
# 80          INDEPEDENCE       1
# 81          LOS ANGELES       1
# 82            ANN ARBOR       1
# 83         GRAVOIS MILL       1
# 84           BOONEVILLE       1
# 85            NASHVILLE       1
# 86          CHILLICOTHE       1
# 87              CLINTON       1
# 88          FORT PIERCE       1
# 89              GARDNER       1
# 90            PEACHTREE       1
# 91            CONCORDIA       1
# 92              RALEIGH       1
# 93           KIRKSVILLE       1
# 94             AMAZONIA       1
# 95           SAINT PAUL       1
# 96                TAMPA       1
# 97              BUCKNER       1
# 98              DE SOTO       1
# 99               DALLAS       1
# 100        BLUR SPRINGS       1
# 101         BRATTLEBORO       1
# 102           LONGBEACH       1
# 103             WICHITA       1
# 104          RIVER BEND       1
# 105      LAKE WINNEBAGO       1
# 106             KILLEEN       1
# 107             GUEYDAN       1
# 108             LINWOOD       1
# 109           NORTHMOOR       1
# 110           BOONVILLE       1
# 111              MEXICO       1
# 112              GALENA       1
# 113         BOLINGBROOK       1
# 114       INDEDPENDENCE       1
# 115      CAPE CANAVERAL       1
# 116            VANDALIA       1
# 117         SPRINGFIELD       1
# 118         INDPENDENCE       1
# 119          FARMINGTON       1
# 120  DESERT HOT SPRINGS       1
# 121            KINGSTON       1
# 122          CENTERVIEW       1
# 123          CEDAR HILL       1
# 124             CHICAGO       1
# 125               OMAHA       1
# 126           LAWERENCE       1
# 127              AUSTIN       1
# 128         LEAVENWORTH       1
# 129          GLADESTONE       1
# 130         HUMANSVILLE       1
# 131               MCGEE       1
# 132         MURPHYSBORO       1
# 133            PECULIAR       1
# 134                GOFF       1
# 135      CARUTHERSVILLE       1
# 136         LITTLE ROCK       1
# 137            LAKELAND       1
# 138        EDWARDSVILLE       1
# 139            TOMPKINS       1
# 140             SEDALIA       1
# 141            LAWRENCE       1
# 142               ATHOL       1
# 143          ST CHARLES       1
# 144            ST LOUIS       1
# 145         PLATTESBURG       1
# 146             PACIFIC       1
# 147           BRADENTON       1
# 148            ROSAMOND       1
# 149               UNION       1
# 150           PLATTE CO       1
# 151       BOWLING GREED       1
# 152                  PL       1
# 153             OAKVIEW       1
# 154       INDEPENDEANCE       1

# %% [markdown]
# - Sort alphabetically, to search for more typos:

# %%
city_counts = KS2['City'].value_counts().reset_index()
city_counts.columns = ['City', 'Count']
# Sort the DataFrame alphabetically by the 'City' column
city_counts = city_counts.sort_values(by='City')
# Display all rows
pd.set_option('display.max_rows', None)  # Show all rows in the output
print(city_counts)
# Out:
#                    City   Count
# 58        0VERLAND PARK       1
# 48                AGNES       2
# 94             AMAZONIA       1
# 82            ANN ARBOR       1
# 142               ATHOL       1
# 43              ATLANTA       2
# 127              AUSTIN       1
# 10               BELTON      79
# 9          BLUE SPRINGS      80
# 46          BLUE SUMMIT       2
# 77        BLUES SPRINGS       1
# 100        BLUR SPRINGS       1
# 113         BOLINGBROOK       1
# 84           BOONEVILLE       1
# 110           BOONVILLE       1
# 151       BOWLING GREED       1
# 147           BRADENTON       1
# 101         BRATTLEBORO       1
# 35             BRIGHTON       3
# 97              BUCKNER       1
# 30              CAMERON       5
# 115      CAPE CANAVERAL       1
# 135      CARUTHERSVILLE       1
# 123          CEDAR HILL       1
# 122          CENTERVIEW       1
# 124             CHICAGO       1
# 86          CHILLICOTHE       1
# 19             CLAYCOMO      15
# 87              CLINTON       1
# 63     COLORADO SPRINGS       1
# 45             COLUMBIA       2
# 91            CONCORDIA       1
# 78              COWGILL       1
# 99               DALLAS       1
# 98              DE SOTO       1
# 120  DESERT HOT SPRINGS       1
# 50           DODGE CITY       2
# 138        EDWARDSVILLE       1
# 66    EL DORADO SPRINGS       1
# 21    EXCELSIOR SPRINGS      13
# 119          FARMINGTON       1
# 61           FLORISSANT       1
# 88          FORT PIERCE       1
# 51               FULTON       2
# 112              GALENA       1
# 89              GARDNER       1
# 129          GLADESTONE       1
# 8             GLADSTONE      87
# 76             GLASTONE       1
# 134                GOFF       1
# 56         GRAIN VALLEY       1
# 4             GRANDVIEW     215
# 83         GRAVOIS MILL       1
# 107             GUEYDAN       1
# 27             HARRISON       5
# 13        HARRISONVILLE      44
# 41         HIGGINSVILLE       2
# 71         HOUSTON LAKE       1
# 130         HUMANSVILLE       1
# 114       INDEDPENDENCE       1
# 6                 INDEP     137
# 80          INDEPEDENCE       1
# 154       INDEPENDEANCE       1
# 2          INDEPENDENCE     366
# 118         INDPENDENCE       1
# 23              JACKSON      10
# 26       JEFFERSON CITY       7
# 0           KANSAS CITY  309805
# 106             KILLEEN       1
# 121            KINGSTON       1
# 73           KINGSVILLE       1
# 93           KIRKSVILLE       1
# 105      LAKE WINNEBAGO       1
# 137            LAKELAND       1
# 34              LANSING       3
# 39            LAS VEGAS       3
# 126           LAWERENCE       1
# 141            LAWRENCE       1
# 128         LEAVENWORTH       1
# 22              LEAWOOD      12
# 17           LEE SUMMIT      17
# 18         LEE'S SUMMIT      17
# 5           LEES SUMMIT     140
# 59           LEESSUMMIT       1
# 49               LENEXA       2
# 60            LEXINGTON       1
# 1               LIBERTY     594
# 53              LICKING       2
# 108             LINWOOD       1
# 136         LITTLE ROCK       1
# 68            LITTLETON       1
# 70                LOGAN       1
# 102           LONGBEACH       1
# 81          LOS ANGELES       1
# 131               MCGEE       1
# 36              MERRIAM       3
# 111              MEXICO       1
# 65                MILLS       1
# 47              MISSION       2
# 38              MOBERLY       3
# 132         MURPHYSBORO       1
# 85            NASHVILLE       1
# 12                  NKC      50
# 55    NORTH BEACH MIAMI       1
# 109           NORTHMOOR       1
# 72           NORTHMOORE       1
# 57            OAK GROVE       1
# 153             OAKVIEW       1
# 28               OLATHE       5
# 125               OMAHA       1
# 15        OVERLAND PARK      24
# 146             PACIFIC       1
# 24            PARKVILLE       7
# 90            PEACHTREE       1
# 133            PECULIAR       1
# 152                  PL       1
# 54            PLATSBURG       2
# 3           PLATTE CITY     245
# 150           PLATTE CO       1
# 40           PLATTE CTY       2
# 37         PLATTE WOODS       3
# 145         PLATTESBURG       1
# 32           PLATTSBURG       4
# 20      PLEASANT VALLEY      14
# 79            PRINCETON       1
# 92              RALEIGH       1
# 42             RANDOLPH       2
# 16              RAYMORE      22
# 7               RAYTOWN     128
# 104          RIVER BEND       1
# 11            RIVERSIDE      61
# 62         ROELAND PARK       1
# 148            ROSAMOND       1
# 95           SAINT PAUL       1
# 74          SAN ANTONIO       1
# 140             SEDALIA       1
# 29              SHAWNEE       5
# 31           SMITHVILLE       4
# 117         SPRINGFIELD       1
# 143          ST CHARLES       1
# 25            ST JOSEPH       7
# 144            ST LOUIS       1
# 33           ST. JOSEPH       4
# 64            ST. LOUIS       1
# 14          SUGAR CREEK      34
# 96                TAMPA       1
# 139            TOMPKINS       1
# 44               TOPEKA       2
# 69                TULSA       1
# 149               UNION       1
# 67                  UNK       1
# 116            VANDALIA       1
# 52               WALNUT       2
# 75      WEST DES MOINES       1
# 103             WICHITA       1

# %%
filtered_data = KS2[KS2['City'] == 'PL']
# Print the filtered DataFrame
display(filtered_data)
# Out:
#                 Reported_Date Reported_Time               From_Date  \
# 81861  03/11/2019 12:00:00 AM         17:41  03/11/2019 12:00:00 AM
#
#               Offense Description Beat                Address City Zip Code  \
# 81861  Misc Violation         NaN  999  5508 N HOMER WHITE RD   PL    64152
#
#       Rep_Dist  Area DVFlag  Fire Arm Used Flag  \
# 81861   PPX063  OSPD      U               False
#
#                                                 Location  \
# 81861  5508 N HOMER WHITE RD\nPL 64152\n(39.194515, -...
#
#                             Geo_Location1
# 81861  POINT (-94.707155998 39.194550006)

# %% [markdown]
# Fix more typos in the city names.

# %%
KS2['City'] = KS2['City'].replace({
    'INDEP': 'INDEPENDENCE',
    'INDEDPENDENCE': 'INDEPENDENCE',
    'INDEPEDENCE': 'INDEPENDENCE',
    'INDEPENDEANCE': 'INDEPENDENCE',
    'ST. JOSEPH': 'ST JOSEPH',
    'INDPENDENCE': 'INDEPENDENCE',
    'BLUES SPRINGS': 'BLUE SPRINGS',
    'BLUR SPRINGS': 'BLUE SPRINGS',
    'BOONEVILLE': 'BOONVILLE',
    'BOWLING GREED': 'BOWLING GREEN',
    'GLADESTONE': 'GLADSTONE',
    'GLASTONE': 'GLADSTONE',
    'LEE SUMMIT': 'LEES SUMMIT',
    "LEE'S SUMMIT": 'LEES SUMMIT',
    'LEESSUMMIT': 'LEES SUMMIT',
    'NORTHMOORE': 'NORTHMOOR',
    'PLATTE CTY': 'PLATTE CITY',
    'PLATTESBURG': 'PLATTSBURG',
    'ST. JOSEPH': 'ST JOSEPH',
    'ST. LOUIS': 'ST LOUIS',
 })

# %%
print(KS2['City'].isna().sum())
# Out:
# 14

# %% [markdown]
# - Change 14 NaN values to 'Unknown'.

# %%
KS2['City'] = KS2['City'].fillna('Unknown')

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312424 entries, 1 to 522904
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Reported_Date       312424 non-null  object
#  1   Reported_Time       312424 non-null  object
#  2   From_Date           312389 non-null  object
#  3   Offense             312424 non-null  object
#  4   Description         255996 non-null  object
#  5   Beat                311344 non-null  object
#  6   Address             312424 non-null  object
#  7   City                312424 non-null  object
#  8   Zip Code            286082 non-null  object
#  9   Rep_Dist            247217 non-null  object
#  10  Area                312424 non-null  object
#  11  DVFlag              312424 non-null  object
#  12  Fire Arm Used Flag  312424 non-null  bool
#  13  Location            272151 non-null  object
#  14  Geo_Location1       312403 non-null  object
# dtypes: bool(1), object(14)
# memory usage: 36.1+ MB

# %% [markdown]
# City column is clean now.

# %% [markdown]
# <h3 style="color: blue;">Clean Reported_Date Column</h3>

# %% [markdown]
# - Check for NaN rows

# %%
nan_Repcount = KS2['Reported_Date'].isna().sum()
print(f"Number of NaN values in 'Reported_Date': {nan_Repcount}")
# Out:
# Number of NaN values in 'Reported_Date': 0

# %% [markdown]
# - Look at Value Counts

# %%
KS2.Reported_Date.value_counts().head(30)
# Out:
# Reported_Date
# 08/14/2023 12:00:00 AM    258
# 07/05/2023 12:00:00 AM    254
# 07/12/2023 12:00:00 AM    245
# 07/24/2023 12:00:00 AM    244
# 06/19/2023 12:00:00 AM    241
# 09/25/2023 12:00:00 AM    240
# 02/12/2024 12:00:00 AM    240
# 01/02/2024 12:00:00 AM    236
# 06/03/2019 12:00:00 AM    235
# 08/09/2023 12:00:00 AM    235
# 08/06/2023 12:00:00 AM    235
# 08/08/2023 12:00:00 AM    234
# 09/11/2023 12:00:00 AM    231
# 07/08/2019 12:00:00 AM    230
# 09/02/2022 12:00:00 AM    230
# 07/10/2023 12:00:00 AM    230
# 07/17/2023 12:00:00 AM    229
# 07/07/2023 12:00:00 AM    229
# 07/01/2022 12:00:00 AM    229
# 08/10/2023 12:00:00 AM    228
# 06/05/2020 12:00:00 AM    227
# 09/18/2023 12:00:00 AM    225
# 08/16/2023 12:00:00 AM    225
# 11/09/2020 12:00:00 AM    224
# 07/18/2023 12:00:00 AM    224
# 08/21/2023 12:00:00 AM    223
# 07/14/2023 12:00:00 AM    222
# 09/29/2023 12:00:00 AM    220
# 10/14/2022 12:00:00 AM    220
# 05/10/2022 12:00:00 AM    220
# Name: count, dtype: int64

# %% [markdown]
# - change Reported_Date to date type. Drop the timestamp of 12:00:00 because all rows have it.

# %%
KS2['Reported_Date'] = pd.to_datetime(KS2['Reported_Date'].str.replace(" 12:00:00 AM", ""), format='%m/%d/%Y')

# %%
# Display the updated DataFrame
print(KS2['Reported_Date'].head())
# Out:
# 1   2020-10-15
# 2   2019-04-25
# 3   2019-06-17
# 4   2019-06-15
# 6   2019-04-12
# Name: Reported_Date, dtype: datetime64[ns]

# %% [markdown]
# <h3 style="color: blue;">Clean Reported_Time Column</h3>

# %% [markdown]
# - Check for NaN

# %%
nan_RepTimecount = KS2['Reported_Time'].isna().sum()
print(f"Number of NaN values in 'Reported_Time': {nan_RepTimecount}")
# Out:
# Number of NaN values in 'Reported_Time': 0

# %% [markdown]
# - Check for missing values

# %%
missing_reported_time_count = KS2['Reported_Time'].isna().sum()
print(f"Number of missing values in 'Reported_Time': {missing_reported_time_count}")
# Out:
# Number of missing values in 'Reported_Time': 0

# %%
print(KS2['Reported_Time'].unique())
# Out:
# ['9:37' '20:51' '2:57' ... '5:32' '5:13' ':']

# %% [markdown]
# - Change to Datetime type

# %%
def clean_time_format(time):
    try:
        return pd.to_datetime(time, format='%H:%M', errors='coerce')
    except Exception:
        return pd.NaT

# %%
KS2['Reported_Time'] = KS2['Reported_Time'].str.strip()

# %% [markdown]
# - Remove whitespace

# %%
KS2['Reported_Time'] = KS2['Reported_Time'].apply(clean_time_format)

# %% [markdown]
# - Check unique values again

# %%
print(KS2['Reported_Time'].unique())
# Out:
# <DatetimeArray>
# ['1900-01-01 09:37:00', '1900-01-01 20:51:00', '1900-01-01 02:57:00',
#  '1900-01-01 17:22:00', '1900-01-01 09:31:00', '1900-01-01 13:15:00',
#  '1900-01-01 14:10:00', '1900-01-01 11:06:00', '1900-01-01 12:46:00',
#  '1900-01-01 20:11:00',
#  ...
#  '1900-01-01 02:34:00', '1900-01-01 04:14:00', '1900-01-01 06:25:00',
#  '1900-01-01 05:44:00', '1900-01-01 06:21:00', '1900-01-01 05:21:00',
#  '1900-01-01 03:37:00', '1900-01-01 05:32:00', '1900-01-01 05:13:00',
#                  'NaT']
# Length: 1441, dtype: datetime64[ns]

# %%
missing_reported_time_count = KS2['Reported_Time'].isna().sum()
print(f"Number of missing values in 'Reported_Time' after cleaning: {missing_reported_time_count}")
# Out:
# Number of missing values in 'Reported_Time' after cleaning: 3

# %%
missing_TimeRows = KS2[KS2['Reported_Time'].isna()]

# Print the rows with missing 'Reported_Time'
print("Rows with missing 'Reported_Time':")
display(missing_TimeRows)
# Out:
# Rows with missing 'Reported_Time':
#       Reported_Date Reported_Time               From_Date  \
# 36852    2019-08-11           NaT  08/11/2019 12:00:00 AM
# 51418    2019-09-29           NaT  09/28/2019 12:00:00 AM
# 64842    2019-07-19           NaT  07/19/2019 12:00:00 AM
#
#                                     Offense               Description Beat  \
# 36852                   Stealing – Shoplift               Shoplifting  345
# 51418  Stealing from Auto (Theft from Auto)  Theft From Motor Vehicle  122
# 64842                   Stealing – Shoplift               Shoplifting  531
#
#                   Address         City Zip Code Rep_Dist Area DVFlag  \
# 36852  11600  E US 40 HWY  KANSAS CITY    64133   PJ3601  EPD      N
# 51418       1300  W 12 ST  KANSAS CITY    64101      NaN  CPD      N
# 64842    1200  W 136TH ST  KANSAS CITY    64145      NaN  SPD      N
#
#        Fire Arm Used Flag                                           Location  \
# 36852               False                                                NaN
# 51418               False  1300  W 12 ST\nKANSAS CITY 64101\n(39.100752, ...
# 64842               False  1200  W 136TH ST\nKANSAS CITY 64145\n(38.88160...
#
#                             Geo_Location1
# 36852  POINT (-94.441099599 39.046482123)
# 51418  POINT (-94.600065031 39.100958011)
# 64842  POINT (-94.606723088 38.881487311)

# %% [markdown]
# - Fill with 12:00, so that these rows do not have to be dropped.

# %%
KS2['Reported_Time'] = KS2['Reported_Time'].fillna(pd.Timestamp('1900-01-01 12:00:00'))

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312424 entries, 1 to 522904
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Reported_Date       312424 non-null  datetime64[ns]
#  1   Reported_Time       312424 non-null  datetime64[ns]
#  2   From_Date           312389 non-null  object
#  3   Offense             312424 non-null  object
#  4   Description         255996 non-null  object
#  5   Beat                311344 non-null  object
#  6   Address             312424 non-null  object
#  7   City                312424 non-null  object
#  8   Zip Code            286082 non-null  object
#  9   Rep_Dist            247217 non-null  object
#  10  Area                312424 non-null  object
#  11  DVFlag              312424 non-null  object
#  12  Fire Arm Used Flag  312424 non-null  bool
#  13  Location            272151 non-null  object
#  14  Geo_Location1       312403 non-null  object
# dtypes: bool(1), datetime64[ns](2), object(12)
# memory usage: 36.1+ MB

# %% [markdown]
# Reported_Date column is clean now.

# %% [markdown]
# <h3 style="color: blue;">Clean From_Date Column</h3>

# %% [markdown]
# - Check for NaN

# %%
nan_FromDateCount = KS2['From_Date'].isna().sum()
print(f"Number of NaN values in 'Reported_Time': {nan_FromDateCount}")
# Out:
# Number of NaN values in 'Reported_Time': 35

# %%
nan_FromDate_rows = KS2[KS2['From_Date'].isna()]
print("Rows with NaN values in 'From_Date':")
display(nan_FromDate_rows)
# Out:
# Rows with NaN values in 'From_Date':
#        Reported_Date       Reported_Time From_Date  \
# 262828                        Miscellaneous Investigation
# 376858                   Stealing from Building/Residence
# 413744                           Alcohol Influence Report
# 416565                           Alcohol Influence Report
#
#                         Description Beat                             Address  \
# 297                             NaN  425                  8900  N HAMPTON RD
# 4894                            NaN  343                   3000  VAN BRUNT S
# 6947                            NaN  112                     1100  LOCUST ST
# 64741                           NaN  425            11000 NW PRAIRIE VIEW RD
# 66052                           NaN  112                     1100  LOCUST ST
# 67096                           NaN  115                      2301 HOLMES ST
# 67564                           NaN  121                LEXINGTON and WABASH
# 68961                           NaN  115                      2301 HOLMES ST
# 70170                           NaN  111                      1125 LOCUST ST
# 70640                           NaN  999                        941 SCOTT AV
# 71389                           NaN  134                4740 PENNSYLVANIA AV
# 71647                           NaN  141                    3212 CAMPBELL ST
# 73768                           NaN  313                      2600  E 8TH ST
# 81098                           NaN  315                5712 INDEPENDENCE AV
# 83005                           NaN  332                      3519 NORTON AV
# 84038            All Other Offenses  123            E 18TH ST and TROOST AVE
# 84204                           NaN  112                     1100  LOCUST ST
# 84868                           NaN  112                      1125 LOCUST ST
# 85242                           NaN  341                       1926 EWING AV
# 87107                           NaN  543                 11416 MANCHESTER AV
# 87361                           NaN  112                      1125 LOCUST ST
# 89176                           NaN  341                       1926 EWING AV
# 89641                           NaN  542                 6827 E BANNISTER RD
# 90721                           NaN  342               E 33 ST/MANCHESTER TR
# 91916                           NaN  112                      1125 LOCUST ST
# 92261                           NaN  243                        7224 E 84 ST
# 98574                           NaN  342               E 33 ST/MANCHESTER TR
# 103947                          NaN  114                    W 28 ST/HOLLY ST
# 109947                          NaN  331                 E 31 ST/PROSPECT AV
# 110786                          NaN  112                      1125 LOCUST ST
# 199277                          NaN  131                 3400  BROADWAY BLVD
# 262828                          NaN  122                     1100  E 10TH ST
# 376858                          NaN  112                      700  WALNUT ST
# 413744                          NaN  133                    4200  WORNALL RD
# 416565  Driving Under the Influence  642  N INDIANA AVE N and NE M 152 HWY W
#
#                City Zip Code Rep_Dist  Area DVFlag  Fire Arm Used Flag  \
# 297     KANSAS CITY    64153   PP0290   NPD  FALSE               False
# 4894    KANSAS CITY      NaN      NaN   EPD      N               False
# 6947    KANSAS CITY    64106   PJ1029   CPD      U               False
# 64741   KANSAS CITY    64153   PP0227   NPD      U               False
# 66052   KANSAS CITY    64160   PJ1029   CPD      U               False
# 67096   KANSAS CITY    64106   PJ1938   CPD      U                True
# 67564   KANSAS CITY      NaN      NaN   CPD      N               False
# 68961   KANSAS CITY    64106   PJ1938   CPD      N                True
# 70170   KANSAS CITY    64106   PJ1029   CPD      U               False
# 70640   KANSAS CITY    66105   PWX001  OSPD      U               False
# 71389   KANSAS CITY    64112   PJ3781   CPD      U               False
# 71647   KANSAS CITY      NaN   PJ2619   CPD      U               False
# 73768   KANSAS CITY    64124   PJ0864   EPD      N               False
# 81098   KANSAS CITY      NaN   PJ0661   EPD      U               False
# 83005   KANSAS CITY    64128   PJ2897   EPD      U               False
# 84038   KANSAS CITY    64127   PJ1496   CPD      N               False
# 413744                  POINT (-94.59128197 39.050439987)
# 416565                 POINT (-94.539149969 39.246169999)
#
#                              Geo_Location1
# 297      POINT (-94.73304996 39.246047695)
# 4894    POINT (-94.520866347 39.070814751)
# 6947     POINT (-94.57741685 39.100885124)
# 64741      POINT (-94.688702987 39.288415)
# 66052    POINT (-94.57741685 39.100885124)
# 67096   POINT (-94.575224004 39.084529983)
# 67564   POINT (-94.552420031 39.110940019)
# 68961   POINT (-94.575224004 39.084529983)
# 70170   POINT (-94.576770968 39.100111983)
# 70640   POINT (-94.633808981 39.088124018)
# 71389   POINT (-94.594211026 39.040802014)
# 71647   POINT (-94.574611035 39.068326004)
# 73768   POINT (-94.551123383 39.103535084)
# 81098   POINT (-94.514881007 39.105353984)
# 83005   POINT (-94.535772984 39.061244009)
# 84038    POINT (-94.570280022 39.09138001)
# 84204    POINT (-94.57741685 39.100885124)
# 84868   POINT (-94.576770968 39.100111983)
# 85242   POINT (-94.503958968 39.085466996)
# 87107   POINT (-94.501181959 38.915977999)
# 87361   POINT (-94.576770968 39.100111983)
# 89176   POINT (-94.503958968 39.085466996)
# 89641   POINT (-94.509863381 38.952407754)
# 90721   POINT (-94.492473352 39.087263219)
# 91916   POINT (-94.576770968 39.100111983)
# 92261     POINT (-94.50345203 38.97223901)
# 98574   POINT (-94.492473352 39.087263219)
# 103947  POINT (-94.598423504 39.084974968)
# 109947  POINT (-94.551466716 39.098145374)
# 110786  POINT (-94.576770968 39.100111983)
# 199277   POINT (-94.590713007 39.06638002)
# 262828  POINT (-94.569723903 39.101975492)
# 376858  POINT (-94.582122981 39.105290994)
# 413744   POINT (-94.59128197 39.050439987)
# 416565  POINT (-94.539149969 39.246169999)

# %% [markdown]
# - change From_Date to date type. Drop the timestamp of 12:00:00 because all rows have it.

# %% [markdown]
# - Borrow date from Reported_Date column to fill in NaN values.

# %%
KS2['From_Date'] = KS2['From_Date'].str.replace(" 12:00:00 AM", "")

# %% [markdown]
# - Change From_Date to datetime type.

# %%
KS2['From_Date'] = pd.to_datetime(KS2['From_Date'], format='%m/%d/%Y', errors='coerce')

# %% [markdown]
# - Borrow date from Reported_Date if From_Date is NaN and Reported_Date is not missing.

# %%
KS2.loc[KS2['From_Date'].isna() & KS2['Reported_Date'].notna(), 'From_Date'] = KS2['Reported_Date']

# %%
KS2.From_Date.value_counts().head(30)
# Out:
# From_Date
# 2020-05-30    303
# 2023-08-01    262
# 2023-06-17    247
# 2023-09-01    247
# 2019-04-01    246
# 2023-09-16    241
# 2020-01-01    241
# 2023-07-01    240
# 2023-06-01    238
# 2022-07-01    238
# 2023-07-07    233
# 2023-09-29    232
# 2023-08-14    230
# 2022-09-02    230
# 2019-06-03    229
# 2023-10-01    228
# 2023-08-10    228
# 2019-11-01    227
# 2023-09-08    227
# 2023-07-15    226
# 2023-07-05    226
# 2023-01-01    226
# 2023-07-02    224
# 2023-07-14    223
# 2023-07-12    223
# 2019-01-01    221
# 2022-05-10    220
# 2022-10-14    220
# 2022-08-11    219
# 2019-10-01    219
# Name: count, dtype: int64

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312424 entries, 1 to 522904
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Reported_Date       312424 non-null  datetime64[ns]
#  1   Reported_Time       312424 non-null  datetime64[ns]
#  2   From_Date           312424 non-null  datetime64[ns]
#  3   Offense             312424 non-null  object
#  4   Description         255996 non-null  object
#  5   Beat                311344 non-null  object
#  6   Address             312424 non-null  object
#  7   City                312424 non-null  object
#  8   Zip Code            286082 non-null  object
#  9   Rep_Dist            247217 non-null  object
#  10  Area                312424 non-null  object
#  11  DVFlag              312424 non-null  object
#  12  Fire Arm Used Flag  312424 non-null  bool
#  13  Location            272151 non-null  object
#  14  Geo_Location1       312403 non-null  object
# dtypes: bool(1), datetime64[ns](3), object(11)
# memory usage: 44.1+ MB

# %% [markdown]
# From_Date column is clean now.

# %% [markdown]
# <h3 style="color: blue;">Clean Offense Column</h3>

# %% [markdown]
# - check for typos:

# %%
offense_counts = KS2['Offense'].value_counts().reset_index()
offense_counts.columns = ['Offense', 'Count']

# Sort the DataFrame alphabetically by the 'Offense' column
offense_counts = offense_counts.sort_values(by='Offense')

pd.set_option('display.max_rows', None)  # Show all rows in the output
display(offense_counts)
# Out:
#                                                Offense  Count
# 241                                                  5      1
# 161                             Abandonment of a Child     36
# 32                                    Abuse of a Child   1852
# 232                               Accidental Drug Over      1
# 206                      Adult Entertainment Violation      3
# 88                                Agg Assault - Domest    388
# 139                               Agg Assault - Drive-     70
# 71                                Aggravated Assault (    534
# 18                            Alcohol Influence Report   4248
# 163                               Animal Abuse/Cruelty     32
# 159                                        Animal Bite     37
# 220                                     Animal Cruelty      2
# 99                                       Armed Robbery    260
# 62                                               Arson    674
# 5                                 Assault (Aggravated)  11689
# 79   Assault (Aggravated) on Department Member/Outs...    435
# 6                             Assault (Non-Aggravated)  11446
# 54   Assault (Non-Aggravated) on Department Member/...    923
# 213                               Attempt Suicide by C      3
# 216                               Attempt Suicide by H      2
# 224                               Attempt Suicide by J      1
# 198                               Attempt Suicide by O      5
# 233                               Attempt Suicide by P      1
# 197                               Attempt Suicide by S      5
# 82                     Attempt to Locate Motor Vehicle    417
# 56                                          Auto Theft    882
# 120                               Auto Theft Outside S    127
# 170                               Bomb Threat/Intimida     19
# 15                          Burglary (Non-Residential)   5777
# 8                               Burglary (Residential)   8488
# 111                               Burglary - Non Resid    179
# 72                                Burglary - Residence    524
# 116                               Burning or Exploding    151
# 133                                         Buy Report     96
# 225                                     CED - Juvenile      1
# 176                        Carrying a Concealed Weapon     16
# 68                                            Casualty    600
# 235                               Casualty (includes a      1
# 93                             Child Custody Violation    312
# 51                                City Weapons Offense   1016
# 12                       City/Municipal Warrant Arrest   6604
# 217                                 Cold Case Homicide      2
# 187                                Confiscated Firearm     10
# 184                                     Counterfeiting     11
# 125                               Credit/Debit/ATM Car    117
# 202                                   Curfew Violation      5
# 49                                           Dead Body   1038
# 222                               Defrauding an Innkee      2
# 177                    Discharge of Firearm (LEO Only)     15
# 27                                  Disorderly Conduct   2963
# 13              Domestic Violence Assault (Aggravated)   6110
# 3           Domestic Violence Assault (Non-Aggravated)  20118
# 74            Domestic Violence Burglary (Residential)    489
# 207  Domestic Violence Lethality Screen for First R...      3
# 30                   Domestic Violence Property Damage   2393
# 121                  Domestic Violence Robbery (Armed)    125
# 97            Domestic Violence Robbery (Strong-Armed)    285
# 113                               Driving Under Influe    157
# 85     Driving While Suspended/Revoked (State Offense)    405
# 228                                        Drunkenness      1
# 140                                        Elder Abuse     62
# 33                   Eluding / Resisting a Lawful Stop   1833
# 58                                        Embezzlement    838
# 64                  Endangering the Welfare of a Child    649
# 134                              Enticement of a Minor     91
# 182                    Escape from Custody/Confinement     11
# 208                                Extortion/Blackmail      3
# 178                                  Failure to Return     13
# 89         Failure to Return Leased or Rented Property    366
# 35                                  Vehicular – Injury   1715
# 96                      Vehicular – Injury Hit and Run    298
# 31                              Vehicular – Non-Injury   2234
# 55                  Vehicular – Non-Injury Hit and Run    914
# 160                               Violation Ex Parte O     37
# 129                               Violation Full Order    103
# 41           Violation of Ex-Parte Order of Protection   1452
# 36               Violation of Full Order of Protection   1692
# 118                               Weapons Law Violatio    133
# 174                                         Wire Fraud     18
# 234                                         auto theft      1
# 238                                              fraud      1
# 237                                          misc viol      1

# %% [markdown]
# listed alphabetically, to see what values can be combined.

# %% [markdown]
# - Clean extra white space

# %%
KS2['Offense'] = KS2['Offense'].str.strip().replace({'–': '-'}, regex=True)

# %%
KS2['Offense'] = KS2['Offense'].str.strip().replace({
    'Stealing - Shoplift': 'Stealing - Shoplifting',
    'Vehicular - Fatality': 'Vehicular – Fatality',
    'auto theft': 'Auto Theft',
    'fraud': 'Fraud / Stealing Through Deceit (Scam/Confidence Game)',
}, regex=True)

# %%
KS2['Offense'] = KS2['Offense'].str.replace(r'\s+', ' ', regex=True)  # Replace multiple spaces with a single space

# %%
offense_counts = KS2['Offense'].value_counts().reset_index()
offense_counts.columns = ['Offense', 'Count']

# Sort the DataFrame alphabetically by the 'Offense' column
offense_counts = offense_counts.sort_values(by='Offense')

# Display all rows
pd.set_option('display.max_rows', None)  # Show all rows in the output
print(offense_counts.head(30))
# Out:
#                                                Offense  Count
# 217                                                  5      1
# 151                             Abandonment of a Child     36
# 31                                    Abuse of a Child   1852
# 221                               Accidental Drug Over      1
# 200                      Adult Entertainment Violation      3
# 84                                Agg Assault - Domest    388
# 130                               Agg Assault - Drive-     70
# 67                                Aggravated Assault (    534
# 16                            Alcohol Influence Report   4248
# 153                               Animal Abuse/Cruelty     32
# 150                                        Animal Bite     37
# 205                                     Animal Cruelty      2
# 95                                       Armed Robbery    260
# 58                                               Arson    674
# 6                                 Assault (Aggravated)  11689
# 75   Assault (Aggravated) on Department Member/Outs...    435
# 7                             Assault (Non-Aggravated)  11446
# 51   Assault (Non-Aggravated) on Department Member/...    923
# 199                               Attempt Suicide by C      3
# 211                               Attempt Suicide by H      2
# 218                               Attempt Suicide by J      1
# 190                               Attempt Suicide by O      5
# 222                               Attempt Suicide by P      1
# 192                               Attempt Suicide by S      5
# 78                     Attempt to Locate Motor Vehicle    417
# 52                                          Auto Theft    883
# 116                               Auto Theft Outside S    127
# 161                               Bomb Threat/Intimida     19
# 14                          Burglary (Non-Residential)   5777
# 10                              Burglary (Residential)   8488

# %% [markdown]
# - Check for Nan

# %%
count_offenseNaN = KS2['Offense'].isna().sum()
print(count_offenseNaN)
# Out:
# 0

# %% [markdown]
# - Check for missing values in Offense column

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312424 entries, 1 to 522904
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Reported_Date       312424 non-null  datetime64[ns]
#  1   Reported_Time       312424 non-null  datetime64[ns]
#  2   From_Date           312424 non-null  datetime64[ns]
#  3   Offense             312424 non-null  object
#  4   Description         255996 non-null  object
#  5   Beat                311344 non-null  object
#  6   Address             312424 non-null  object
#  7   City                312424 non-null  object
#  8   Zip Code            286082 non-null  object
#  9   Rep_Dist            247217 non-null  object
#  10  Area                312424 non-null  object
#  11  DVFlag              312424 non-null  object
#  12  Fire Arm Used Flag  312424 non-null  bool
#  13  Location            272151 non-null  object
#  14  Geo_Location1       312403 non-null  object
# dtypes: bool(1), datetime64[ns](3), object(11)
# memory usage: 44.1+ MB

# %% [markdown]
# Offense column is clean now.

# %% [markdown]
# <h3 style="color: blue;">Clean Description Column</h3>

# %% [markdown]
# - Check for NaN

# %%
count_DescripNaN = KS2['Description'].isna().sum()
print(count_DescripNaN)
# Out:
# 56428

# %%
KS2['Description'] = KS2['Description'].str.strip()

# %%
desc_counts = KS2['Description'].value_counts().reset_index()
desc_counts.columns = ['Description', 'Count']

# Sort the DataFrame alphabetically by the 'Offense' column
desc_counts = desc_counts.sort_values(by='Description')

pd.set_option('display.max_rows', None)  # Show all rows in the output
display(desc_counts)
# Out:
#                                  Description  Count
# 4                         Aggravated Assault  18916
# 8                          All Other Larceny  12072
# 9                         All Other Offenses  10737
# 46                            Animal Cruelty     33
# 30                                     Arson    707
# 49       Assisting or Promoting Prostitution     27
# 47                                Bad Checks     31
# 57                        Betting / Wagering      2
# 58                                   Bribery      1
# 5             Burglary/Breaking and Entering  14317
# 48                       Commercial Sex Acts     31
# 22                  Counterfeiting / Forgery   1889
# 19            Credit Card / Automatic Teller   2641
# 51  Curfew / Loitering / Vargancy Violations     18
# 53                        DV Related Suicide     11
# 16                        Disorderly Conduct   3137
# 13               Driving Under the Influence   5142
# 15                Drug / Narcotic Violations   4761
# 26                 Drug Equipment Violations    878
# 52                               Drunkenness     13
# 28                              Embezzlement    784
# 38                     Extortion / Blackmail    113
# 20                 False Pretenses / Swindle   2629
# 24               Family Offenses, Nonviolent   1221
# 31                         Forcible Fondling    545
# 23                             Forcible Rape   1325
# 27                           Forcible Sodomy    825
# 40               Hacking / Computer Invasion     76
# 18                            Identity Theft   2855
# 45                             Impersonation     48
# 50                                    Incest     21
# 14                              Intimidation   4980
# 54                     Involuntary Servitude      8
# 56                      Justifiable Homicide      6
# 34                    Kidnapping / Abduction    199
# 41                     Liquor Law Violations     69
# 55                Manslaughter by Negligence      6
# 1                        Motor Vehicle Theft  29211
# 29                                    Murder    726
# 59                               Peeping Tom      1
# 32                            Pocket-Picking    209
# 37            Pornography / Obscene Material    115
# 35                              Prostitution    186
# 42                   Purchasing Prostitution     68
# 36                           Purse-Snatching    129
# 12                                   Robbery   6286
# 43             Sexual Assault With An Object     61
# 7                                Shoplifting  12304
# 0                             Simple Assault  30250
# 60                          Sports Tampering      1
# 33                            Statutory Rape    208
# 17                  Stolen Property Offenses   2890
# 11                       Theft From Building   8309
# 44          Theft From Coin-Operated Machine     57
# 3                   Theft From Motor Vehicle  23006
# 6     Theft of Vehicle Parts and Accessories  12670
# 10                 Trespass of Real Property   8884
# 2          Vandalism/Destruction of Property  26126
# 21                     Weapon Law Violations   2050
# 39                             Welfare Fraud     81
# 25                                Wire Fraud   1094

# %%
# Fill NaN values in the 'Description' column with 'No Description'
KS2['Description'] = KS2['Description'].fillna('No Description')

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312424 entries, 1 to 522904
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Reported_Date       312424 non-null  datetime64[ns]
#  1   Reported_Time       312424 non-null  datetime64[ns]
#  2   From_Date           312424 non-null  datetime64[ns]
#  3   Offense             312424 non-null  object
#  4   Description         312424 non-null  object
#  5   Beat                311344 non-null  object
#  6   Address             312424 non-null  object
#  7   City                312424 non-null  object
#  8   Zip Code            286082 non-null  object
#  9   Rep_Dist            247217 non-null  object
#  10  Area                312424 non-null  object
#  11  DVFlag              312424 non-null  object
#  12  Fire Arm Used Flag  312424 non-null  bool
#  13  Location            272151 non-null  object
#  14  Geo_Location1       312403 non-null  object
# dtypes: bool(1), datetime64[ns](3), object(11)
# memory usage: 44.1+ MB

# %% [markdown]
# Description column is clean now.

# %% [markdown]
# <h3 style="color: blue;">Clean Beat Column</h3>

# %%
KS2.Beat.value_counts()
# Out:
# Beat
# 345             10303
# 113              9691
# 134              8558
# 133              8025
# 112              7502
# 111              6158
# 115              6038
# 312              5900
# 132              5732
# 234              5532
# 121              5267
# 241              5247
# 221              5129
# 422              5057
# 131              4989
# 123              4799
# 242              4716
# 341              4693
# 233              4678
# 635              4506
# 542              4482
# 533              4408
# 342              4367
# 314              4305
# 535              4277
# 232              4269
# 213              4175
# 331              4143
# 641              4093
# 531              4072
# 322              3991
# 543              3956
# 313              3857
# 421              3791
# 534              3783
# 211              3769
# 332              3757
# 323              3748
# 212              3685
# 231              3682
# 642              3652
# 141              3501
# 311              3449
# 532              3422
# 344              3403
# 223              3368
# 122              3310
# 333              3290
# 343              3179
# 334              3166
# 632              3118
# 315              3093
# 222              3066
# 142              2885
# 321              2879
# 411              2816
# 631              2813
# 224              2801
# 545              2786
# 324              2774
# 144              2771
# 415              2678
# 243              2596
# 643              2588
# 114              2578
# 414              2537
# 544              2522
# 423              2451
# 999              2430
# 636              2382
# 412              2298
# 633              2221
# 634              2218
# 125              2165
# 413              2052
# 425              2033
# 143              1838
# 124              1545
# 424              1168
# 644              1015
# 541               566
# 0                 110
# OSPD               98
# 509                36
# CPD                29
# 225                22
# 215                21
# EPD                21
# 9999               18
# MPD                17
# 346                16
# 235                14
# 325                14
# 547                14
# 539                13
# 316                13
# 228                13
# 335                12
# 230                11
# 340                10
# 226                10
# 320                10
# 546                 9
# 245                 9
# 145                 9
# 135                 9
# 416                 8
# 140                 8
# 120                 7
# 309                 7
# 109                 7
# 146                 6
# CW                  6
# 119                 6
# 227                 6
# 310                 6
# 116                 6
# 336                 5
# 216                 5
# 317                 5
# 214                 5
# 246                 5
# 330                 5
# 238                 4
# 210                 4
# 511                 4
# NPD                 4
# 236                 4
# 244                 3
# 639                 3
# SPD                 3
# 110                 3
# KCK                 3
# 240                 3
# 117                 3
# 218                 3
# 537                 3
# 130                 3
# 220                 2
# 510                 2
# 410                 2
# 1754                2
# 523                 2
# MPD222              2
# 136                 2
# PATROL              2
# EAST                2
# 239                 2
# 349                 2
# 611                 2
# 409                 2
# 24`                 1
# 64108               1
# 147                 1
# 219A                1
# OUTSIDE             1
# GRANDVIEW           1
# 338                 1
# SCD                 1
# KANSASCITYKS        1
# BELTON              1
# PARKED              1
# 844                 1
# 645                 1
# 420                 1
# 3045                1
# 375                 1
# 20                  1
# 256                 1
# CP                  1
# 445                 1
# 149                 1
# 428                 1
# 675                 1
# 200                 1
# UNK                 1
# 219                 1
# 64124               1
# 1                   1
# 524                 1
# 565                 1
# 512                 1
# 2099                1
# 376                 1
# 522                 1
# 676                 1
# 612                 1
# 525                 1
# 4111                1
# 31                  1
# 441                 1
# 566                 1
# 431                 1
# 5335                1
# 433                 1
# 328                 1
# 129                 1
# UNKNOWN             1
# 530                 1
# 310A                1
# 399                 1
# 6332                1
# 426                 1
# 162                 1
# 3222                1
# Name: count, dtype: int64

# %%
# Fill NaN values in the 'Description' column with 'No Description'
KS2['Beat'] = KS2['Beat'].fillna('Unknown')

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312424 entries, 1 to 522904
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Reported_Date       312424 non-null  datetime64[ns]
#  1   Reported_Time       312424 non-null  datetime64[ns]
#  2   From_Date           312424 non-null  datetime64[ns]
#  3   Offense             312424 non-null  object
#  4   Description         312424 non-null  object
#  5   Beat                312424 non-null  object
#  6   Address             312424 non-null  object
#  7   City                312424 non-null  object
#  8   Zip Code            286082 non-null  object
#  9   Rep_Dist            247217 non-null  object
#  10  Area                312424 non-null  object
#  11  DVFlag              312424 non-null  object
#  12  Fire Arm Used Flag  312424 non-null  bool
#  13  Location            272151 non-null  object
#  14  Geo_Location1       312403 non-null  object
# dtypes: bool(1), datetime64[ns](3), object(11)
# memory usage: 44.1+ MB

# %%
print(KS2['Beat'].isna().sum())
# Out:
# 0

# %% [markdown]
# Beat column is clean now.

# %% [markdown]
# <h3 style="color: blue;">Clean Address Column</h3>

# %%
KS2.Address.value_counts().head(40)
# Out:
# Address
# 11600  E US 40 HWY        2791
# 8500  N BOARDWALK AVE     1415
# 100  E LINWOOD BLVD       1165
# 11600  E US 40 HWY E      1072
# 2300  HOLMES ST           1068
# 2300  E MEYER BLVD        1028
# 1100  TROOST AVE           935
# 1700  W 133RD ST           703
# 8600  WARD PKWY            635
# 2600  PROSPECT AVE         593
# 100  E 13TH ST             589
# 1300  CHERRY ST            557
# 00  S WATER ST             556
# 1100  LOCUST ST            513
# 500  WESTPORT RD           491
# 3200  N AMERISTAR DR       490
# 3700  BROADWAY BLVD        482
# 3800  BROADWAY BLVD        474
# 8300  N CHURCH RD          419
# 4400  WORNALL RD           418
# 7600  PROSPECT AVE         417
# 4100  BROADWAY BLVD        411
# 4800  N OAK TRFY           399
# 00  W PERSHING RD          382
# 6400  MANCHESTER AVE       375
# 3100  PROSPECT AVE         372
# 1800  E FRONT ST           369
# 8400  N MADISON AVE        368
# 4000  MILL ST              366
# 8500  STATE LINE RD        359
# 2400  GILLHAM RD           355
# 4300  MAIN ST              345
# 9700  MARION PARK DR       337
# 8500  N MADISON AVE        335
# 4300  N CORRINGTON AVE     335
# 1000  BERKLEY PKWY         331
# 3200  INDEPENDENCE AVE     326
# 11800  BLUE RIDGE BLVD     326
# 9200  NE BARRY RD          315
# 9300  BALES DR             309
# Name: count, dtype: int64

# %% [markdown]
# Address column is clean.

# %% [markdown]
# <h3 style="color: blue;">Clean Zip Code Column</h3>

# %% [markdown]
# - get rid of space in 'Zip Code'

# %%
KS2.rename(columns={'Zip Code': 'Zipcode'}, inplace=True)

# %%
KS2.Zipcode.value_counts()
# Out:
# Zipcode
# 64111        20740
# 64130        17513
# 64127        16419
# 64108        14490
# 64106        13497
# 64132        12515
# 64133        11842
# 64131        11673
# 64134        11001
# 64128        10794
# 64114         9718
# 64124         9224
# 64110         8993
# 64109         8740
# 64129         7225
# 64118         7023
# 64105         6598
# 64117         6362
# 64112         5884
# 64123         5597
# 64138         5532
# 64151         5483
# 64137         5369
# 64119         5362
# 64154         5229
# 64155         5009
# 64116         4530
# 64153         4354
# 64120         3959
# 64126         3925
# 64157         2923
# 64145         2548
# 64125         1865
# 64113         1840
# 64158         1744
# 64152         1637
# 64161         1586
# 64156         1047
# 64136          810
# 64147          730
# 64102          574
# 64101          555
# 64068          518
# 64139          478
# 64146          356
# 64079          205
# 64030          205
# 64050          176
# 64086          131
# 64055           97
# 64012           89
# 64163           82
# 64149           73
# 64015           73
# 6411            59
# 64115           53
# 64052           45
# 64150           45
# 64165           44
# 64104           39
# 64164           33
# 64053           30
# 64054           27
# 64064           24
# 64056           23
# 64701           23
# 64121           22
# 64083           19
# 64217           19
# 64122           19
# 66160           16
# 64160           15
# 64103           15
# 64061           15
# 66101           14
# 66211           14
# 99999           13
# 66104           12
# 6410            12
# 64148           12
# 64057           11
# 6413            10
# 64018           10
# 64016            9
# 66106            9
# 64107            9
# 64014            8
# 64166            8
# 64081            7
# 63137            7
# 66102            7
# 64141            7
# 66103            7
# 46988            6
# 66105            6
# 64135            6
# 66210            6
# 63110            5
# 64318            5
# 64011            4
# 63440            4
# 433327                           1200  WESTPORT RD  KANSAS CITY    6411
# 432980                           1200  WESTPORT RD  KANSAS CITY    6411
# 279607                            5400  EUCLID AVE  KANSAS CITY    6411
# 432944                           1200  WESTPORT RD  KANSAS CITY    6411
# 428374                           1200  WESTPORT RD  KANSAS CITY    6411
# 279134                           1200  WESTPORT RD  KANSAS CITY    6411
# 521227                             1200  W 45TH ST  KANSAS CITY    6411
# 146566                           1200  WESTPORT RD  KANSAS CITY    6411
# 65355                                4100  WARWICK  KANSAS CITY    6411
# 80734                               4000  MCGEE ST  KANSAS CITY    6411
# 94469                          3900  BALTIMORE AVE  KANSAS CITY    6411
# 109050                         3700  BROADWAY BLVD  KANSAS CITY    6411
# 277195                           1200  WESTPORT RD  KANSAS CITY    6411
# 124411                          4600  JEFFERSON ST  KANSAS CITY    6411
# 139196                            3600  CENTRAL ST  KANSAS CITY    6411
# 39313                       4000  PENNSYLVANIA AVE  KANSAS CITY    6411
# 145732                            5400  EUCLID AVE  KANSAS CITY    6411
# 39026                   E 31ST ST and CHESTNUT AVE  KANSAS CITY    6411
# 153799                           1200  WESTPORT RD  KANSAS CITY    6411
# 35926                          3800  BROADWAY BLVD  KANSAS CITY    6411
# 49956                   E 31ST ST and CHESTNUT AVE  KANSAS CITY    6411
# 199515                         MO 210 and BRIGHTON  KANSAS CITY    6411
# 251093                           1200  WESTPORT RD  KANSAS CITY    6411
# 238754                           1200  WESTPORT RD  KANSAS CITY    6411
# 25973                          3700  BROADWAY BLVD  KANSAS CITY    6411
# 513337                      4000  PENNSYLVANIA AVE  KANSAS CITY    6411
# 202602                           1200  WESTPORT RD  KANSAS CITY    6411
# 220344                           1200  WESTPORT RD  KANSAS CITY    6411
# 22505                                3600  MAIN ST  KANSAS CITY    6411
# 184638  E VOLKER AVE NE and N BRUCE WATKINS HWY NE  KANSAS CITY    6412
# 63734                  E TRUMAN RD and JACKSON AVE  KANSAS CITY    6412
# 439238               WARD PKWY S and BELLEVIEW AVE  KANSAS CITY    6412
# 34176                                  6600  PASEO  KANSAS CITY    6412
# 116866               BLUE RIDGE BLVD and 107TH TER  KANSAS CITY    6413
# 115511                       9500  BLUE RIDGE BLVD  KANSAS CITY    6413
# 128719                              100  E 65TH ST  KANSAS CITY    6413
# 25294                             8500  E 109TH ST  KANSAS CITY    6413
# 489930                       9500  BLUE RIDGE BLVD  KANSAS CITY    6413
# 487299                        6400  MANCHESTER AVE  KANSAS CITY    6413
# 486794                        6400  MANCHESTER AVE  KANSAS CITY    6413
# 41507                 GRANDVIEW RD and CYPRESS AVE  KANSAS CITY    6413
# 175139                          1200  E MEYER BLVD  KANSAS CITY    6413
# 511649                       9500  BLUE RIDGE BLVD  KANSAS CITY    6413
# 19363                          9200  WASHINGTON ST  KANSAS CITY    6414
# 369327                        8000  N STODDARD AVE  KANSAS CITY    6415
# 345653                               00  W 10TH ST  KANSAS CITY    6415
# 312330                        8000  N STODDARD AVE  KANSAS CITY    6415
# 66573                    E TRUMAN RD and HOLMES ST  KANSAS CITY    6418
# 147001                   NE 42 TER and DAVIDSON RD  KANSAS CITY    6419
# 389025                     1200  BELLEFONTAINE AVE  KANSAS CITY    6427
# 143278                             500  E 105TH ST  KANSAS CITY    6431
# 157973                             500  E 105TH ST  KANSAS CITY    6431
# 269658                          8700  CHESTNUT CIR  KANSAS CITY    6432
# 51646                             7900  E 117TH ST  KANSAS CITY    6434
# 291937                       9300  OLD SANTA FE RD  KANSAS CITY    6438
# 58911                         8300  N ST CLAIR AVE  KANSAS CITY    6451
# 428473                       7700  NW ROANRIDGE RD  KANSAS CITY    6451
#
#        Rep_Dist  Area DVFlag  Fire Arm Used Flag  \
# 201875      NaN  OSPD      N               False
# 463997      NaN   CPD  FALSE               False
# 211662      NaN   CPD  FALSE               False
# 132124      NaN   CPD      N               False
# 38564    PJ6266   MPD      N               False
# 209779      NaN   SPD  FALSE               False
# 496887      NaN   SPD  FALSE               False
# 116262   PJ6843   SPD      N               False
# 29492       NaN   SPD      N               False
# 444773      NaN   NPD  FALSE               False
# 33430       NaN   NPD      N               False
# 154719   PJ5341   MPD      N               False
# 141581   PJ5341   MPD      N               False
# 155242   PJ5341   MPD      N               False
# 195830   PJ5341   MPD      N               False
# 148935   PJ5341   MPD      N               False
# 77839    PJ0391   CPD      N               False
# 170983      NaN   CPD      N               False
# 168925   PJ5341   MPD      N                True
# 161902   PJ5341   MPD      N               False
# 158948   PJ5341   MPD      N               False
# 155021   PJ5341   MPD      N               False
# 141489   PJ5341   MPD      N                True
# 424071      NaN   CPD  FALSE               False
# 424137      NaN   CPD  FALSE               False
# 421961      NaN   CPD  FALSE               False
# 379934   PJ3185   CPD  FALSE               False
# 333486   PJ3267   CPD  FALSE               False
# 288314      NaN   CPD  FALSE               False
# 285226      NaN   CPD  FALSE               False
# 282426   PJ4359   MPD  FALSE               False
# 281518      NaN   CPD  FALSE               False
# 395394      NaN   CPD  FALSE               False
# 424492      NaN   CPD  FALSE                True
# 224848   PJ6959   SPD  FALSE                True
# 432816      NaN   CPD  FALSE               False
# 507683      NaN   CPD  FALSE               False
# 504896      NaN   CPD  FALSE               False
# 498341      NaN   CPD  FALSE               False
# 493932      NaN   CPD  FALSE               False
# 491884      NaN   CPD  FALSE               False
# 488102      NaN   CPD  FALSE               False
# 486858      NaN   CPD  FALSE               False
# 481064      NaN   CPD  FALSE               False
# 478808      NaN   CPD  FALSE               False
# 474465      NaN   CPD  FALSE               False
# 466399      NaN   CPD  FALSE               False
# 465081      NaN   CPD  FALSE               False
# 462516      NaN   CPD  FALSE               False
# 459766      NaN   CPD  FALSE               False
# 454565      NaN   CPD  FALSE               False
# 446684      NaN   CPD  FALSE               False
# 437814      NaN   CPD  FALSE               False
# 433327      NaN   CPD  FALSE               False
# 432980      NaN   CPD  FALSE               False
# 279607   PJ4359   MPD  FALSE               False
# 432944      NaN   CPD  FALSE               False
# 428374      NaN   CPD  FALSE               False
# 279134      NaN   CPD  FALSE               False
# 521227      NaN   CPD  FALSE               False
# 146566      NaN   CPD      N               False
# 65355       NaN   CPD      Y               False
# 80734       NaN   CPD      N               False
# 94469    PJ3132   CPD      N               False
# 109050      NaN   CPD      N               False
# 277195      NaN   CPD  FALSE               False
# 124411      NaN   CPD      N               False
# 139196      NaN   CPD      N               False
# 39313    PJ3185   CPD      N               False
# 145732   PJ4359   MPD      Y               False
# 39026    PJ2489   EPD      N               False
# 153799      NaN   CPD      N               False
# 35926    PJ3045   CPD      N               False
# 49956    PJ2489   EPD      N                True
# 199515      NaN   SCP  FALSE               False
# 251093      NaN   CPD  FALSE               False
# 238754      NaN   CPD  FALSE               False
# 25973    PJ2968   CPD      N               False
# 513337   PJ3185   CPD  FALSE               False
# 202602      NaN   CPD  FALSE               False
# 220344      NaN   CPD  FALSE               False
# 22505    PJ2900   CPD      N               False
# 184638      NaN   MPD      N               False
# 63734    PJ1367   EPD      N               False
# 439238   PJ3832   MPD  FALSE               False
# 34176    PJ5133   MPD      N                True
# 116866      NaN   SPD      N               False
# 115511      NaN   SPD      N               False
# 128719   PJ4995   MPD      Y               False
# 25294    PJ6985   SPD      N               False
# 489930      NaN   SPD  FALSE                True
# 487299      NaN   MPD   TRUE               False
# 486794      NaN   MPD   TRUE               False
# 41507    PJ6853   SPD      N               False
# 175139      NaN   MPD      N               False
# 511649      NaN   SPD  FALSE               False
# 19363    PJ6344   MPD      N               False
# 369327      NaN   NPD  FALSE               False
# 345653      NaN   CPD  FALSE               False
# 312330      NaN   NPD  FALSE               False
# 66573    PJ1308   CPD      N               False
# 147001      NaN   SCP      N               False
# 389025   PJ1164   EPD  FALSE               False
# 143278   PJ6764   SPD      N               False
# 157973   PJ6764   SPD      N               False
# 269658      NaN   MPD  FALSE               False
# 51646    PJ7274   SPD      N               False
# 291937      NaN   SPD  FALSE               False
# 58911       NaN   NPD      N               False
# 428473      NaN   NPD  FALSE               False
#
#                                                  Location  \
# 201875                                                NaN
# 463997                         POINT (-94.56933 39.10313)
# 211662                       POINT (-94.569355 39.103103)
# 132124                                                NaN
# 38564   600  W 89TH TER\nKANSAS CITY 6114\n(38.966212,...
# 209779                       POINT (-94.583443 38.948324)
# 496887                         POINT (-94.58305 38.94831)
# 116262  8300  E 105TH TER\nKANSAS CITY 6134\n(38.93353...
# 29492   5100  LONGVIEW RD\nKANSAS CITY 6137\n(38.91653...
# 444773                         POINT (-94.65543 39.23365)
# 33430   9100  NW SKYVIEW AVE\nKANSAS CITY 6154\n(39.26...
# 154719  7000  PROSPECT AVE\nKANSAS CITY 6410\n(38.9996...
# 141581  7000  PROSPECT AVE\nKANSAS CITY 6410\n(38.9996...
# 155242  7000  PROSPECT AVE\nKANSAS CITY 6410\n(38.9996...
# 195830  7000  PROSPECT AVE\nKANSAS CITY 6410\n(38.9996...
# 148935  7000  PROSPECT AVE\nKANSAS CITY 6410\n(38.9996...
# 77839   200  WALNUT ST\nKANSAS CITY 6410\n(41.236488, ...
# 170983  300  W 8TH ST\nKANSAS CITY 6410\n(39.10463, -9...
# 168925  7000  PROSPECT AVE\nKANSAS CITY 6410\n(38.9996...
# 161902  7000  PROSPECT AVE\nKANSAS CITY 6410\n(38.9996...
# 158948  7000  PROSPECT AVE\nKANSAS CITY 6410\n(38.9996...
# 155021  7000  PROSPECT AVE\nKANSAS CITY 6410\n(38.9996...
#
# 291937   POINT (-94.508351001 38.95553702)
# 58911   POINT (-94.646939442 39.244900607)
# 428473   POINT (-94.65543256 39.233556023)

# %% [markdown]
# Look up correct Zipcode for Address:
# https://tools.usps.com/zip-code-lookup.htm?byaddress

# %%
KS2['Zipcode'] = KS2['Zipcode'].replace('6114', '64114')
KS2['Zipcode'] = KS2['Zipcode'].replace('6131', '64131')
KS2['Zipcode'] = KS2['Zipcode'].replace('6134', '64134')
KS2['Zipcode'] = KS2['Zipcode'].replace('6137', '64137')
KS2['Zipcode'] = KS2['Zipcode'].replace('6151', '64151')
KS2['Zipcode'] = KS2['Zipcode'].replace('6154', '64154')

KS2['Zipcode'] = KS2['Zipcode'].replace('6410', '64132')
KS2['Zipcode'] = KS2['Zipcode'].replace('6411', '64111')
KS2['Zipcode'] = KS2['Zipcode'].replace('6414', '64114')
KS2['Zipcode'] = KS2['Zipcode'].replace('6432', '64131')

# %%
print(KS2['Zipcode'].unique())
# Out:
# [nan '64068' '64130' '64114' '64133' '64153' '64132' '64161' '64126'
#  '64106' '64050' '64055' '64127' '64112' '64128' '64109' '64119' '64138'
#  '64155' '64111' '64110' '64117' '64152' '64012' '64123' '64120' '64108'
#  '64116' '64131' '64030' '64129' '64134' '64086' '64124' '64157' '64102'
#  '64061' '64149' '64118' '64158' '64147' '64151' '64146' '64156' '64105'
#  '64125' '66044' '66206' '66160' '66210' '60654' '64052' '64137' '64154'
#  '64014' '64145' '64113' '66101' '64136' '64079' '64101' '64054' '64053'
#  '54139' '66103' '64121' '64056' '64166' '64015' '64150' '65542' '64139'
#  '64199' '63137' '66411' '66203' '64115' '64107' '63016' '64018' '64104'
#  '66109' '61133' '64019' '64148' '64122' '65102' '64650' '64024' '61437'
#  '65251' '53154' '66064' '66061' '64217' '67801' '66215' '64163' '92240'
#  '64011' '66104' '66205' '65153' '66412' '65129' '66211' '64313' '64506'
#  '63440' '64218' '64016' '64515' '6413' '66012' '63131' '34127' '65802'
#  '64064' '34128' '66112' '99999' '64081' '64032' '32920' '63128' '6412'
#  '64083' '46988' '60440' '66106' '64165' '64103' '64141' '54157' '64159'
#  '64415' '65152' '64038' '65265' '64999' '64082' '64344' '64477' '61431'
#  '6434' '64008' '66223' '66204' '64000' '70542' '76549' '64701' '34130'
#  '6451' '64314' '64034' '65138' '64164' '64214' '61126' '64048' '64160'
#  '6418' '34123' '63132' '64135' '65147' '66062' '64331' '64301' '54154'
#  '64140' '66105' '64492' '66043' '64010' '89142' '61406' '61119' '54127'
#  '64213' '64045' '64144' '66314' '65158' '89169' '34231' '24127' '65156'
#  '64257' '66118' '54134' '64057' '90802' '66214' '72714' '65155' '64013'
#  '64522' '46111' '63134' '65714' '63084' '641303016' '66102' '54137'
#  '64428' '64190' '64501' '64429' '64143' '64318' '63130' '54111' '64312'
#  '66110' '66111' '61438' '93560' '34208' '64142' '63145' '67204' '64195'
#  '640681329' '6110' '54130' '66932' '60126' '61132' '64063' '6431' '64058'
#  '66114' '63124' '6419' '33803' '66208' '72209' '64051' '64100' '66209'
#  '64192' '66428' '64321' '61408' '50023' '72601' '61134' '64078' '66213'
#  '62966' '67214' '34982' 'CLAY' '5301' '66126' '6106' '80120' '89104'
#  '64167' '65151' '74110' '64744' '82604' '63147' '80922' '66293' '61441'
#  '66202' '65157' '63033' '64075' '33179' '64029' '78207' '6438' '66616'
#  '75219' '63020' '6415' '64909' '64183' '64421' '63501' '63301' '64031'
#  '27604' '64020' '30269' '68118' '64037' '50266' '69110' '6427' '64505'
#  '30301' '64089' '64601' '65201' 'MO' '38305' '37203' '65037' '63110'
#  '48105' '90018' '60145' '64637']

# %% [markdown]
# - replace NaN with 'Unknown'

# %%
KS2['Zipcode'] = KS2['Zipcode'].fillna('Unknown')

# %%
print(KS2['Zipcode'].isna().sum())
# Out:
# 0

# %% [markdown]
# Zipcode column is clean.

# %% [markdown]
# <h3 style="color: blue;">Clean Rep_Dist Column</h3>

# %%
KS2.Rep_Dist.value_counts().head(40)
# Out:
# Rep_Dist
# PJ3601    4092
# PP0321    1977
# PJ4990    1493
# PJ2650    1243
# PJ1938    1130
# PJ1046    1064
# PJ6174     927
# PP0317     895
# PJ7404     881
# PC0323     876
# PC1130     859
# PJ1177     844
# PC0282     694
# PJ1029     671
# PJ6566     641
# PJ1191     583
# PP0285     580
# PJ7081     570
# PJ5921     546
# PC0387     535
# PJ2169     517
# PC1343     516
# PJ3792     498
# PJ0375     488
# PC0863     486
# PJ5702     476
# PP0402     466
# PJ4889     459
# PJ3132     457
# PJ3045     454
# PJ3303     454
# PC1444     438
# PC0788     429
# PJ3226     412
# PJ0218     403
# PJ3218     392
# PJ3492     391
# PC0430     391
# PJ1831     387
# PJ2572     361
# Name: count, dtype: int64

# %%
print(KS2.Rep_Dist.isna().sum())
# Out:
# 65207

# %%
KS2['Rep_Dist'] = KS2['Rep_Dist'].fillna('Unknown')

# %%
print(KS2.Rep_Dist.isna().sum())
# Out:
# 0

# %% [markdown]
# Rep_Dist is now clean.

# %% [markdown]
# <h3 style="color: blue;">Clean DVFlag Column</h3>

# %%
KS2.DVFlag.value_counts()
# Out:
# DVFlag
# FALSE    180211
# N         95289
# Y         13810
# TRUE      13425
# U          9689
# Name: count, dtype: int64

# %% [markdown]
# - replace TRUE with Y, and FALSE with N

# %%
KS2['DVFlag'] = KS2['DVFlag'].replace({True: 'Y', False: 'N'})

KS2['DVFlag'] = KS2['DVFlag'].replace({
    'Y': 'Y',
    'TRUE': 'Y',
    'N': 'N',
    'FALSE': 'N',
    'U': 'Unknown'  # or whatever you want for unknowns
})

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312424 entries, 1 to 522904
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Reported_Date       312424 non-null  datetime64[ns]
#  1   Reported_Time       312424 non-null  datetime64[ns]
#  2   From_Date           312424 non-null  datetime64[ns]
#  3   Offense             312424 non-null  object
#  4   Description         312424 non-null  object
#  5   Beat                312424 non-null  object
#  6   Address             312424 non-null  object
#  7   City                312424 non-null  object
#  8   Zipcode             312424 non-null  object
#  9   Rep_Dist            312424 non-null  object
#  10  Area                312424 non-null  object
#  11  DVFlag              312424 non-null  object
#  12  Fire Arm Used Flag  312424 non-null  bool
#  13  Location            272151 non-null  object
#  14  Geo_Location1       312403 non-null  object
# dtypes: bool(1), datetime64[ns](3), object(11)
# memory usage: 44.1+ MB

# %%
KS2.DVFlag.value_counts()
# Out:
# DVFlag
# N          275500
# Y           27235
# Unknown      9689
# Name: count, dtype: int64

# %%
DV_length = len(KS2.DVFlag)

# %%
dv_yes = KS2['DVFlag'].value_counts().get('Y', 0)

# %%
# Calculate the percentage
percentage_dv = (dv_yes / DV_length) * 100

# %%
print(f"The percentage of Domestic Violence instances is {percentage_dv:.2f}%.")
# Out:
# The percentage of Domestic Violence instances is 8.72%.

# %% [markdown]
# DVFlag is clean now.

# %% [markdown]
# <h3 style="color: blue;">Clean 'Fire Arm Used Flag' Column</h3>

# %%
KS2.rename(columns={'Fire Arm Used Flag': 'FireArmUsed'}, inplace=True)

# %%
KS2.FireArmUsed.value_counts()
# Out:
# FireArmUsed
# False    295786
# True      16638
# Name: count, dtype: int64

# %%
total_incidents = len(KS2['FireArmUsed'])

# %%
firearm_incidents = KS2['FireArmUsed'].value_counts().get(True, 0)

# %%
percentage_firearm = (firearm_incidents / total_incidents) * 100

# %%
print(f"{percentage_firearm:.2f}% of the incidences involved a firearm.")
# Out:
# 5.33% of the incidences involved a firearm.

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312424 entries, 1 to 522904
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Reported_Date  312424 non-null  datetime64[ns]
#  1   Reported_Time  312424 non-null  datetime64[ns]
#  2   From_Date      312424 non-null  datetime64[ns]
#  3   Offense        312424 non-null  object
#  4   Description    312424 non-null  object
#  5   Beat           312424 non-null  object
#  6   Address        312424 non-null  object
#  7   City           312424 non-null  object
#  8   Zipcode        312424 non-null  object
#  9   Rep_Dist       312424 non-null  object
#  10  Area           312424 non-null  object
#  11  DVFlag         312424 non-null  object
#  12  FireArmUsed    312424 non-null  bool
#  13  Location       272151 non-null  object
#  14  Geo_Location1  312403 non-null  object
# dtypes: bool(1), datetime64[ns](3), object(11)
# memory usage: 44.1+ MB

# %% [markdown]
# FireArmUsed column is clean now.

# %%
KS2.Location.value_counts().head(25)
# Out:
# Location
# POINT (-94.44114 39.04643)                                           1010
# POINT (-94.441099599 39.046482123)                                    901
# POINT (-94.657201087 39.250189469)                                    778
# 1100  TROOST AVE\nKANSAS CITY 64106\n(39.10068, -94.569846)           453
# POINT (-94.583430529 39.068442506)                                    377
# 2300  E MEYER BLVD\nKANSAS CITY 64132\n(39.007141, -94.559903)        366
# 2300  HOLMES ST\nKANSAS CITY 64108\n(39.084583, -94.575809)           343
# POINT (-94.557774977 39.008867004)                                    315
# 2600  PROSPECT AVE\nKANSAS CITY 64127\n(39.078772, -94.552412)        280
# POINT (-94.576183983 39.084744979)                                    277
# 100  E LINWOOD BLVD\nKANSAS CITY 64111\n(39.068419, -94.584002)       274
# 8500  N BOARDWALK AVE\nKANSAS CITY 64154\n(39.252223, -94.655534)     273
# POINT (-94.58351 39.06839)                                            270
# 1700  W 133RD ST\nKANSAS CITY 64145\n(38.886576, -94.605578)          223
# POINT (-94.57628 39.09833)                                            222
# POINT (-94.605034997 38.887799005)                                    215
# POINT (-94.590592656 39.053219759)                                    214
# 8600  WARD PKWY\nKANSAS CITY 64114\n(38.971462, -94.605386)           211
# 9700  MARION PARK DR\nKANSAS CITY 64137\n(38.950149, -94.536077)      207
# POINT (-94.57579 39.08484)                                            206
# POINT (-94.575809 39.084583)                                          202
# POINT (-94.65713 39.25013)                                            198
# POINT (-94.577132982 39.097717986)                                    197
# POINT (-94.5599 39.00713)                                             191
# POINT (-94.594776516 39.246582532)                                    188
# Name: count, dtype: int64

# %%
KS2.Location.isna().sum()
# Out:
# 40273

# %%
KS2['Location'] = KS2['Location'].fillna('Unknown')

# %%
KS2.Location.isna().sum()
# Out:
# 0

# %% [markdown]
# <h3 style="color: blue;">Clean Geo_Location1 Column</h3>

# %%
KS2.Geo_Location1.isna().sum()
# Out:
# 21

# %%
KS2['Geo_Location1'] = KS2['Geo_Location1'].fillna('Unknown')

# %%
KS2.Geo_Location1.isna().sum()
# Out:
# 0

# %%
KS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312424 entries, 1 to 522904
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Reported_Date  312424 non-null  datetime64[ns]
#  1   Reported_Time  312424 non-null  datetime64[ns]
#  2   From_Date      312424 non-null  datetime64[ns]
#  3   Offense        312424 non-null  object
#  4   Description    312424 non-null  object
#  5   Beat           312424 non-null  object
#  6   Address        312424 non-null  object
#  7   City           312424 non-null  object
#  8   Zipcode        312424 non-null  object
#  9   Rep_Dist       312424 non-null  object
#  10  Area           312424 non-null  object
#  11  DVFlag         312424 non-null  object
#  12  FireArmUsed    312424 non-null  bool
#  13  Location       312424 non-null  object
#  14  Geo_Location1  312424 non-null  object
# dtypes: bool(1), datetime64[ns](3), object(11)
# memory usage: 44.1+ MB

# %% [markdown]
# Geo_Location1 column is clean now.

# %% [markdown]
# <h3 style="color: blue;">All columns are clean now.</h3>

# %% [markdown]
# <h1 style="color: blue;">Exploratory Data Analysis</h1>

# %% [markdown]
# <h3 style="color: blue;">Look at Domestic Violence, by Zipcode</h3>

# %%
zip_dv_count = KS2.groupby(['Zipcode', 'DVFlag']).size().unstack(fill_value=0)

# %% [markdown]
# Only grab DVFlag of 500 or more.

# %%
zip_dv_count = zip_dv_count[zip_dv_count.sum(axis=1) >= 500]

# %%
#Check if Y exists
if 'Y' in zip_dv_count.columns:
    zip_dv_count = zip_dv_count[['Y']]
else:
    print("No 'Y' values found in DVFlag.")

# %%
# Sort by count (ascending order)
zip_dv_count = zip_dv_count.sort_values(by='Y', ascending=True)

# %%
if not zip_dv_count.empty:
    fig, ax = plt.subplots(figsize=(18, 10))  # Use subplots to define figure size
    ax.clear()
    
    zip_dv_count.plot(kind='bar', stacked=True, ax=ax)
    
    ax.set_title('Domestic Violence by Zip Code (500+ incidences)', fontsize=24) 
    ax.set_xlabel('Zip Code', fontsize=16) 
    ax.set_ylabel('Count of Y', fontsize=16) 

    ax.legend(fontsize=14)
    
    plt.xticks(rotation=45, fontsize=14)
    plt.yticks(fontsize=14)
    
    plt.tight_layout()  # Adjust layout to prevent clipping
    
    plt.show()
else:
    print("No zip codes with 500 or more Domestic Violence instances.")

# %% [markdown]
# - Highest Domestic Violence incidences... "Unknown" Zipcode.
# - 2nd highest ... Zipcode 64130 is in the Metro Police Department beat, in the central south of Kansas City, MO.
# - 3rd highest ... Zipcode 64127 is in the Central Police Department beat, in the center west part of Kansas City, MO.
# - 4th highest ... Zipcde 64132 is in the Metro Police Department beat.
# - 5th highest ... Zipcode 64134 is also in the South Police Department beat.
# - 6th highest ... Zipcode 64131 is in the Metro Police Department beat.

# %% [markdown]
# Aside from Unknown Zipcodes, most of the incidence of Domestic Violence is in the Metro Police Department beat.

# %% [markdown]
# <h3 style="color: blue;">Look at Domestic Violence, by Area (police beat)</h3>

# %%
Area_dv_count = KS2.groupby(['Area', 'DVFlag']).size().unstack(fill_value=0)

# %%
# Filter to only keep the 'Unknown' and 'Y' columns
filtered_area_dv_count = Area_dv_count[['Unknown', 'Y']]

# %%
# Sort by 'Y' count in descending order
sorted_filtered_area_dv_count = filtered_area_dv_count.sort_values(by='Y', ascending=False)

# %%
# Create a third column that sums the 'Y' count and 'Unknown' count
sorted_filtered_area_dv_count['Total'] = sorted_filtered_area_dv_count['Y'] + sorted_filtered_area_dv_count['Unknown']

# %%
print(sorted_filtered_area_dv_count)
# Out:
# DVFlag   Unknown     Y  Total
# Area
# EPD         2650  7308   9958
# MPD         1790  6410   8200
# CPD         2622  4648   7270
# SPD         1124  3769   4893
# SCP          823  2737   3560
# NPD          543  1978   2521
# Unknown       85   249    334
# OSPD          52   136    188

# %% [markdown]
# - The East Police Department (EPD) has the highest amount of Domestic violence incidences.
# - The Metro Police Department (MPD) has the 2nd highest amount.
# - The Central Police Department (CPD) has the 3rd highest.

# %% [markdown]
# <h3 style="color: blue;">Look at Incidents with Firearms, by Zipcode</h3>

# %%
KS2.FireArmUsed.value_counts()
# Out:
# FireArmUsed
# False    295786
# True      16638
# Name: count, dtype: int64

# %%
zip_firearm_count = KS2.groupby(['Zipcode', 'FireArmUsed']).size().unstack(fill_value=0)

# %%
print(zip_firearm_count.columns)
# Out:
# Index([False, True], dtype='bool', name='FireArmUsed')

# %%
# Sort by count (ascending order)
zip_firearm_count = zip_firearm_count.sort_values(by=True, ascending=False)
print(zip_firearm_count.head(10))
# Out:
# FireArmUsed  False  True
# Zipcode
# Unknown      24487   1855
# 64130        15699   1814
# 64127        15030   1389
# 64128         9745   1049
# 64132        11485   1042
# 64134        10151    851
# 64124         8418    806
# 64131        10943    733
# 64110         8400    593
# 64111        20209    590

# %%
# Filter to keep only the rows where FireArmUsed is True
true_firearm_count = zip_firearm_count[True]
print(true_firearm_count.head(30))
# Out:
# Zipcode
# Unknown    1855
# 64130      1814
# 64127      1389
# 64128      1049
# 64132      1042
# 64134       851
# 64124       806
# 64131       733
# 64110       593
# 64111       590
# 64109       559
# 64108       474
# 64106       465
# 64129       462
# 64133       455
# 64123       412
# 64138       384
# 64126       356
# 64114       254
# 64137       246
# 64117       199
# 64118       182
# 64119       164
# 64125       156
# 64116       128
# 64120       126
# 64151       111
# 64105       106
# 64155        98
# 64112        76
# Name: True, dtype: int64

# %% [markdown]
# - create bar graph with FireArmUsed, by Zipcode

# %%
zip_firearm_count = KS2.groupby(['Zipcode', 'FireArmUsed']).size().unstack(fill_value=0)
true_firearm_count = zip_firearm_count[True]

# %%
# Filter counts greater than 250
true_firearm_count = true_firearm_count[true_firearm_count > 250]

# %%
# Sort the true firearm count in ascending order
true_firearm_count = true_firearm_count.sort_values(ascending=True)

# %% [markdown]
# Only show incidences more than 250, so that graph is readable.

# %%
plt.figure(figsize=(20, 18))

true_firearm_count.plot(kind='bar', color='blue')
plt.title('Incidence of Fire Arm Used, by Zipcode', fontsize=24) 
plt.xlabel("Zipcode", fontsize=20) 
plt.ylabel("Count of Firearm Used", fontsize=20) 
plt.xticks(rotation=45, fontsize=16)  
plt.yticks(fontsize=16)  
plt.tight_layout()

plt.grid(axis='y', linestyle='--', alpha=0.9, linewidth=1.5)

plt.show()

# %% [markdown]
# - The most incidences of Fire Arm Used is from "Unknown" Zipcodes.
# - The 2nd most incidences is from Zipcode 64130, in the Metro PD beat.
# - The 3rd most incidences is from Zipcode 64127, in the Central PD beat.
# - The 4th most incidences is from Zipcode 64128, in the Central PD beat.
# - The 5th most incidences is from Zipcode 64132, in the Metro PD beat.
# - the 6th most incidences is from Zipcode 64134, in the South PD beat.

# %% [markdown]
# Aside from the incidences of Firearm Used, in the "Unknown" Zipcodes, two of the top 5 Zipcodes are in the Matro PD beat, and two are in the Central PD beat.

# %% [markdown]
# These Zipcodes were also in the top 5 for incidences of Domestic Violence:
# - 64130
# - 64127
# - 64132
# - 64134

# %% [markdown]
# Two of these 3 are in the Metro Police Department beat.

# %% [markdown]
# <h3 style="color: blue;">Look at various types of incidents, by Zipcode</h3>

# %% [markdown]
# Look at Stealing or Robbery, Harassment or Intimidation, Rape or Sex or Molestation, Assault, Murder or Casualty, Kidnapping or Trafficking, Missing Person

# %% [markdown]
# - Look at Stealing or Robbery

# %%
filtered_StealRob_count = KS2[KS2['Offense'].str.contains('Steal|Robbery', case=False)]

# %%
# Group by 'Zipcode' and count occurrences of filtered offenses
zip_StealRob_count = filtered_StealRob_count.groupby('Zipcode').size().sort_values(ascending=True)

# %%
zip_StealRob_count = zip_StealRob_count[zip_StealRob_count > 50]

# %%
plt.figure(figsize=(20, 18))

zip_StealRob_count.plot(kind='bar', color='red')
plt.title('Incidence of Stealing or Robbery Greater than 50 Incidences, by Zipcode', fontsize=24) 
plt.xlabel("Zipcode", fontsize=20) 
plt.ylabel("Count of Stealing or Robbery", fontsize=20) 
plt.xticks(rotation=45, fontsize=16)  
plt.yticks(fontsize=16)  
plt.tight_layout()

plt.grid(axis='y', linestyle='--', alpha=0.7, linewidth=1.5) 

plt.show()

# %% [markdown]
# These are the Zipcodes with the most incidences of Stealing and Robbery:
# - 64111
# - 64133
# - "Unknown" Zipcodes
# - 64108
# - 64114
#
# Zipcode 64111 has double the amount of Stealing and Robbery incidences than almost all of the Zipcodes and 3 times the amount than most of the Zipcodes.

# %% [markdown]
# - Look at Harassment or Intimidation

# %%
filtered_HarassIntim_count = KS2[KS2['Offense'].str.contains('Harassment|Intimidation', case=False)]

# %%
# Group by 'Zipcode' and count occurrences of filtered offenses
zip_HarassIntim_count = filtered_HarassIntim_count.groupby('Zipcode').size()

# %%
zip_HarassIntim_count = zip_HarassIntim_count.sort_values(ascending=True)

# %%
plt.figure(figsize=(20, 18))

zip_HarassIntim_count.plot(kind='bar', color='black')
plt.title('Incidence of Harassment or Intimidation, by Zipcode', fontsize=24) 
plt.xlabel("Zipcode", fontsize=20) 
plt.ylabel("Count of Harassment or Intimidation", fontsize=20) 
plt.xticks(rotation=45, fontsize=16)  
plt.yticks(fontsize=16)  
plt.tight_layout()

plt.grid(axis='y', linestyle='--', alpha=0.9, linewidth=1.5)

plt.show()

# %% [markdown]
# - "Unknown" Zipcode has the most incidences of Harassment and Intimidation.
# - The 2nd most incidences of Stealing and Robbery are in Zipcode 64130.
# - the 3rd most incidences of Stealing and Robbery are in Zipcode 64132
# - the 4th most incidences of Stealing and Robbery are in Zipcode 64134
# - the 5th most incidences of Stealing and Robbery are in Zipcode 64131
# - the 6th most incidences of Stealing and Robbery are in Zipcode 64127
#
# The Zipcodes with almost zero incidences of Harassment and Intimidation are:
# - 64115
# - 64121
# - 89104
# - 64140
# - 64183
# - 66106
# - 66204
# - 64103
# - 66209
# - 80120
# - 64086
# - 64064
# - 64055
# - 64018

# %% [markdown]
# - Look at  Rape or Sex or Molestation, by Zipcode

# %%
filtered_R_S_M_count = KS2[KS2['Offense'].str.contains('Rape|Sex|Molest', case=False)]

# %%
# Group by 'Zipcode' and count occurrences of filtered offenses
zip_R_S_M_count = filtered_R_S_M_count.groupby('Zipcode').size()

# %%
# Filter to only include those Zipcodes which also exist in filtered_Assault_count and have counts greater than 50
filtered_Assault_count = KS2[KS2['Offense'].str.contains('Assault', case=False)]
filtered_Assault_count = filtered_Assault_count.groupby('Zipcode').size()

# %%
# Only keep Zipcodes with Assault counts greater than 50
zip_R_S_M_count = zip_R_S_M_count[zip_R_S_M_count.index.isin(filtered_Assault_count[filtered_Assault_count > 50].index)].sort_values(ascending=True)

# %%
plt.figure(figsize=(24, 18))

zip_R_S_M_count.plot(kind='bar', color='lightblue')
plt.title('Incidence of Rape or Sex or Molestation, Greater than 50, by Zipcode', fontsize=32)
plt.xlabel("Zipcode", fontsize=28)  # Increased font size
plt.ylabel("Count of Rape / Sex / Molestation", fontsize=28)
plt.xticks(rotation=45, fontsize=20)  
plt.yticks(fontsize=20)  
plt.tight_layout()

plt.grid(axis='y', linestyle='--', alpha=0.9, linewidth=1.5)

plt.show()

# %% [markdown]
# Most incidences of Rape / Sex / Molestation by Zipcode
#
# - 64127
# - 64130
# - 64111
# - 64108
# - 64134
# - 64106
# - 64132
#
# Zipcodes 64127 and 64130 have much higher incidences than all other Zipcodes. 64127 has double the amount of incidences of most of the Zipcodes, and triple the amount of many of the Zipcodes.

# %% [markdown]
# - Look at incidences of Assault, by Zipcode

# %%
filtered_Assault_count = KS2[KS2['Offense'].str.contains('Assault', case=False)] 
filtered_Assault_count = filtered_Assault_count.groupby('Zipcode').size()

# %%
# Filter only assaults greater than 50
filtered_Assault_count = filtered_Assault_count[filtered_Assault_count > 50].sort_values(ascending=True)

# %%
plt.figure(figsize=(24, 18))

filtered_Assault_count.plot(kind='bar', color='purple')
plt.title('Incidence of Assault, Greater than 50, by Zipcode', fontsize=32)
plt.xlabel("Zipcode", fontsize=28) 
plt.ylabel("Count of Assault", fontsize=28)
plt.xticks(rotation=45, fontsize=20)  
plt.yticks(fontsize=20)  
plt.tight_layout()

plt.grid(axis='y', linestyle='--', alpha=0.9, linewidth=1.5)

plt.show()

# %% [markdown]
# Aside from "Unknown" Zipcodes, the Zipcodes with the most incidences of Assault are:
# - 64130
# - 64127
# - 64132
# - 64128
# - 64134
#
# Again, Zipcode 64130 has double the amount of Assault incidences than most Zipcodes, and triple the amount of Assault incidences than many Zipcodes.

# %% [markdown]
# - Look at Murder or Casualty incidences, by Zipcode

# %%
filtered_Murd_Casualty_count = KS2[KS2['Offense'].str.contains('Murder|Casualty', case=False)]

# %%
filtered_Murd_Casualty_count = filtered_Murd_Casualty_count.groupby('Zipcode').size().sort_values(ascending=True)

# %%
plt.figure(figsize=(24, 18))

filtered_Murd_Casualty_count.plot(kind='bar', color='yellow')
plt.title('Incidence of Murder or Casualty, by Zipcode', fontsize=32)
plt.xlabel("Zipcode", fontsize=28) 
plt.ylabel("Count of Murder or Casualty", fontsize=28)
plt.xticks(rotation=45, fontsize=20)  
plt.yticks(fontsize=20)  
plt.tight_layout()

plt.grid(axis='y', linestyle='--', alpha=0.9, linewidth=1.5)

plt.show()

# %% [markdown]
# Zipcodes with the highest incidences of Murder or Casualty:
# - 64130
# - 64127
# - 64128
# - 64132
# - 64111
#
# Again, Zipcodes 64130 and 64127 are highest in crime.

# %% [markdown]
# - Look for incidences of Kidnapping or Trafficking or Missing Person

# %%
filtered_Kid_Traf_Miss_count = KS2[KS2['Offense'].str.contains('Kidnapping|Trafficking|Missing', case=False)]

# %%
filtered_Kid_Traf_Miss_count = filtered_Kid_Traf_Miss_count.groupby('Zipcode').size().sort_values(ascending=True)

# %%
plt.figure(figsize=(24, 18))

filtered_Kid_Traf_Miss_count.plot(kind='bar', color='hotpink')
plt.title('Incidence of Kidnapping or Trafficking or Missing Person, by Zipcode', fontsize=32)
plt.xlabel("Zipcode", fontsize=28) 
plt.ylabel("Count of Kidnapping / Trafficking / Missing Person", fontsize=28)
plt.xticks(rotation=45, fontsize=20)  
plt.yticks(fontsize=20)  
plt.tight_layout()

plt.grid(axis='y', linestyle='--', alpha=0.9, linewidth=1.5)

plt.show()

# %% [markdown]
# The highest amount of incidences of Kidnapping, Trafficking, or Missing Persons is from "Unknown" Zipcodes.
#
# Aside from "Unknown" Zipcodes, these are the Zipcodes with the highest incidences:
# - 64130
# - 64127
# - 64132
# - 64134
# - 64124
#
# Again, Zipcodes 64130 ad 64127 top the charts.

# %% [markdown]
# <h1 style="color: blue;">Conclusion</h1>

# %% [markdown]
# ## Top Zipcodes for Highest Crime Incidence
#
# The following Zipcodes are consistently at the top for the highest incidence of crime across nearly every category:
#
# - 64130
# - 64127
#
# Both of these Zipcodes are located in the East Police Department Division.
#
# ---
# ## Crime Categories with Highest Incidence Rates
# - The Zipcodes 64130 and 64127 have **double the incidence rate** compared to most other Zipcodes in these categories:
#   - **Domestic Violence**
#   - **Firearm Used**
#   - **Rape or Sexual Assault**
#   - **Assault**
#   - **Murder or Casualty**
#   - **Kidnapping, Trafficking, or Missing Person**
#
# ---
# ## Additional Insights
# - **64130** and **64132** demonstrate the highest incidences of crime in **harassment or intimidation**, with **double the incidence rate** than most other Zipcodes.
# - Even though **64127** is not at the very top for this category, it still shows double the incidence rate compared to nearly all other Zipcodes.
#
# ---
# ## Notable Incidence
# - 64111 records the highest incidences for:
#   - **Stealing or Robbery**
